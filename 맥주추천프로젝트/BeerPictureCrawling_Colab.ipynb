# %%
# import moduels
import requests # for crawling
from bs4 import BeautifulSoup # for crawling
import pandas as pd # for handle DataFrame
import numpy as np # for handle DataFrame
import os # for handle local environment
import re # for handel str()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class BeerPictureCrawling(object):
    beers = list() # 전역변수 beers
    
    def __init__(self): # instance 변수 사용 안함 
        pass
    
    # 1. 다운 받을 맥주 이름 불러오고 list로 변경
    def To_list(self, column_name):
        self.column_name = column_name
        
        Beer_names_df = pd.read_csv("/content/drive/My Drive/beer_name.csv", encoding='utf-8')
        beer_names = list(Beer_names_df[column_name])
        beer_names.sort() 

        # beers에 담기 
        for beer in beer_names:
            beer = beer + " beer" # beer를 넣어야 검색 효율성이 증대

            # 특수문자를 제거함으로써 검색 효율성 증대 + 오류 방지
            parsed_beer = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', '', beer)

            # 구글은 + 문자를 인식하므로, 공백을 + 로 대체 
            parsed_beer = parsed_beer.replace(" ","+")
            
            # beers 리스트에 append 
            BeerPictureCrawling.beers.append(parsed_beer)
            
        return BeerPictureCrawling.beers
            
    # 2. 구글 이미지 검색으로 requests 요청
    def BeerCrawling(self):
        count = 0 # 결과 수를 count
        error_count = 0 # 에러 수를 count
        error_list = list() # error가 뜬 맥주를 확인하기 위한 error list()
        
        ##############################################################################
        
        # 폴더 생성 code
        BASE_DIR = "/content/drive/My Drive"
        PICTURE_DIR = os.path.join(BASE_DIR, 'beer_pictures')

        # 만약 경로가 없으면, 새로운 폴더를 생성하겠습니다.
        if not os.path.exists(PICTURE_DIR):
            os.makedirs(PICTURE_DIR) 
        
        ##############################################################################
        
        # Crawling codes    
        for b in BeerPictureCrawling.beers:
            try:
                filename= b.replace("+"," ")[:-5] + ".png" # png 형식의 파일 
                print(filename)
                BASE_URL = "https://www.google.com/search"
                params = {
                    'tbm': 'isch',
                    'q': b,
                    'tbs': 'ic:specific,isc:white'
                }

                resp = requests.get(BASE_URL, params=params)
                # print(resp)
                # print(resp.url)
                
                soup = BeautifulSoup(resp.content, 'html.parser')
                # print(soup)

                beer_tag = str(soup.find_all('a')[40]) # 가져올 이미지 링크가 존재하는 tag
                # print(beer_tag)
                
                if "spell=1" in beer_tag: # "이것을 찾으셨나요?, 수정된 검색어에 대한 결과" tag
                    beer_tag = str(soup.find_all('a')[41])
                    if "nfpr=1" in beer_tag: # "다음 검색어로 대신 검색" tag
                        beer_tag = str(soup.find_all('a')[42])
                    else:
                        pass
                else:
                    pass

                beer_picture_url = beer_tag.split(" ")[-2].replace("src=","").replace('"',"")
                # print(beer_picture_url)

                img_resp = requests.get(beer_picture_url)
                # print(resp2)

                beers_picture_path = os.path.join(PICTURE_DIR, filename)
                with open(beers_picture_path, 'wb') as f:
                    f.write(img_resp.content) # 이미지 파일 쓰기

                count += 1

            except:
                error_list.append(b)
                error_count += 1
                pass

        # 문자열 추가 
        print("전체 맥주의 수: ", len(BeerPictureCrawling.beers)) # 전체 맥주 이름 list 
        print("\n수집된 맥주의 수: ", count) # 실제로 수집된 맥주 수 
        print("\n에러가 난 맥주의 수: ", error_count) # 에러가 발생한 맥주 수 
        print("\n0?", len(BeerPictureCrawling.beers) - (count + error_count)) # 0이 나와야 정상
        print("\n Error List: \n", error_list)

# %%
Test = BeerPictureCrawling()

# %%
Test.To_list('name')
# Out:
# ['+100+beer',
#  '1812+beer',
#  '19+beer',
#  '3+Monts+Amber+Ale+On+Lees+beer',
#  '3+Monts+Flanders+Golden+Ale+beer',
#  '4+Pines+Dry+Stout+beer',
#  '90+Wee+Heavy+beer',
#  'APA+beer',
#  'Aaron+beer',
#  'Aass+Bayer+Aass+Dark+beer',
#  'Aass+Bock+beer',
#  'Aass+Genuine+Pilsner+beer',
#  'Aass+Juleøl+beer',
#  'Abbaye+Des+Rocs+Grand+Cru+Belgian+Special+Brown+beer',
#  'Abbaye+Des+Rocs+Brasserie+Des+Rocs+Brune+beer',
#  'Abrahadabra+beer',
#  'Abricot+Du+Fermier+beer',
#  'Abt+12+beer',
#  'Abt+12+Oak+Aged+beer',
#  'Ace+Of+Spades+beer',
#  'Achel+Trappist+Extra+beer',
#  'Adnams+TallyHo+beer',
#  'Aecht+Schlenkerla+Eiche+beer',
#  'Aecht+Schlenkerla+Fastenbier+beer',
#  'Aecht+Schlenkerla+Helles+Lagerbier+beer',
#  'Aecht+Schlenkerla+Kräusen+beer',
#  'Aecht+Schlenkerla+Rauchbier+Märzen+beer',
#  'Aecht+Schlenkerla+Rauchbier+Urbock+beer',
#  'Aecht+Schlenkerla+Rauchbier+Weizen+beer',
#  'Agamemnon+beer',
#  'Agent+Provocateur+beer',
#  'Akevitt+beer',
#  'AlIksir+beer',
#  'Ale+Gâteau+ForêtNoire+beer',
#  'Alpha+Pale+Ale+beer',
#  'Altbier+beer',
#  'Alter+Ego+beer',
#  'Amager++Grassroots++Shadow+Pictures++Skyggebilleder+beer',
#  'Amager++Jester+King++Danish+Metal+beer',
#  'Amager++Mikkeller++Hr+Frederiksens+Væsel+Brunch+beer',
#  'Amager++Mikkeller++Hr+Frederiksens+Væsel+Brunch++BarrelAged+beer',
#  'Amager++Surly++Todd+The+Axe+Man+beer',
#  'Amarillo+beer',
#  'Amarillo+Single+Hop+IPA+beer',
#  'Amarsi+Double+IPA+beer',
#  'Amazing+Haze+beer',
#  'American+Barley+Wine+beer',
#  'Anabasis+beer',
#  'Andechs+Weissbier+Dunkel+beer',
#  'Andechser+Doppelbock+Dunkel+beer',
#  'Andechser+Vollbier+Hell+beer',
#  'Andechser+Weissbier+Hell+beer',
#  'Angelus+beer',
#  'Aniara+beer',
#  'Ann+beer',
#  'Anosteke+beer',
#  'Aon+Pecan+Mud+Cake+beer',
#  'Aphrodisiaque+beer',
#  'Ardenne+Blond+beer',
#  'Assassin+beer',
#  'Atrial+Rubicite+beer',
#  'Augustiner+Bräu+Lagerbier+Hell+beer',
#  'Augustiner+Bräu+Maximator+beer',
#  'Augustiner+Bräu+Märzen+Bier+beer',
#  'Augustiner+Bräu+Oktoberfestbier+beer',
#  'Augustiner+Bräu+Weissbier+beer',
#  'Aurora+beer',
#  'Avec+Les+Bons+Voeux+beer',
#  'Ayinger+Altbairisch+Dunkel+beer',
#  'Ayinger+Bräuweisse+beer',
#  'Ayinger+Jahrhundert+Bier+beer',
#  'Ayinger+KirtaHalbe+beer',
#  'Ayinger+Maibock+beer',
#  'Ayinger+Oktober+FestMärzen+beer',
#  'Ayinger+UrWeisse+beer',
#  'Ayinger+Weizenbock+beer',
#  'Ayinger+Winterbock+beer',
#  'BB+Dexi+beer',
#  'BB10+beer',
#  'Baciami+Lipsia+Kiss+My+Lips+beer',
#  'Back+Hand+Of+God+Stout+beer',
#  'Backbone+Splitter+beer',
#  'Baden+Baden+1999+Bitter+Ale+beer',
#  'Baden+Baden+Dark+Ale+Stout+beer',
#  'Baden+Baden+Golden+beer',
#  'Baden+Baden+Red+Ale+Especial+beer',
#  'Baird+Angry+Boy+Brown+Ale+beer',
#  'Bairisch+Pils+beer',
#  'Baladin+Nora+beer',
#  'Barleywine+Ale+beer',
#  'Baronen+beer',
#  'Barrel+Aged+Imperial+German+Chocolate+Cupcake+Stout+beer',
#  'Barrel+Full+Of+Monkeys+Imperial+Stout+beer',
#  'BarrelAged+Abraxas+beer',
#  'Beamish+Irish+Stout+beer',
#  'Beatification+beer',
#  'Bedarö+Bitter+beer',
#  'Beer+Geek+Breakfast+beer',
#  'Beer+Geek+Brunch+Weasel+beer',
#  'Beer+Geek+Brunch+Weasel+Bourbon+Edition+beer',
#  'Beer+Geek+Brunch+Weasel+Islay+Edition+beer',
#  'Beer+Geek+Brunch+Weasel++Cognac+Edition+beer',
#  'Beer+Geek+Cocoa+Shake+beer',
#  'Beer+Geek+Dessert+beer',
#  'Beer+Geek+Vanilla+Maple+Shake+beer',
#  'Beer+Geek+Vanilla+Shake+beer',
#  'Beer+Geek+Vanilla+Shake++Bourbon+BarrelAged+beer',
#  'Beer+Hop+Breakfast+beer',
#  'BeerBarrelTime+beer',
#  'BeerBera+beer',
#  'Beersel+Mattina+beer',
#  'Beglo+beer',
#  'Bellerose+Biere+Blonde+Extra+beer',
#  'Belô+Petroleum+beer',
#  'Benno+beer',
#  'Bernard+Bohemian+Ale+beer',
#  'Bernard+Cerne+Dark+beer',
#  'Best+Extra+Stout+beer',
#  'Bestefar+beer',
#  'Beyond+Good+And+Evil+beer',
#  'Bianca+beer',
#  'Bianca+Mango+Lassi+Gose+beer',
#  'Biere+Aux+Marrons+beer',
#  'Biere+DAbbaye+Lacu+beer',
#  'Big+Worster+beer',
#  'Bishops+Farewell+beer',
#  'Bière+De+Noël+beer',
#  'Bière+Nouvelle+beer',
#  'Black+Albert+beer',
#  'Black+Ball+Porter+beer',
#  'Black+Betty+beer',
#  'Black+Boss+Porter+beer',
#  'Black+Damnation+II++Mocha+Bomb+beer',
#  'Black+Damnation+V++Double+Black+beer',
#  'Black+Gold+beer',
#  'Black+Magic+Woman+beer',
#  'Black+Malts+And+Body+Salts+beer',
#  'Black+Note+Stout+beer',
#  'Black+Oak+Ten+Bitter+Years+beer',
#  'Black+Shark+beer',
#  'Black+Tokyo+Horizon+beer',
#  'Black+Tuesday+beer',
#  'Blackstone+Porter+beer',
#  'Bloed+Zweet++Tranen+beer',
#  'Blåbær+Lambik+beer',
#  'Bohemia+Clásica+beer',
#  'Bohemia+Oscura+beer',
#  'Bohemia+Weizen+beer',
#  'Boltmaker+formerly+Best+Bitter+beer',
#  'Bommen++Granaten+beer',
#  'Bonator+beer',
#  'Boon+Oude+Kriek+Mariage+Parfait+beer',
#  'Boris+Imperial+Stout+beer',
#  'Boss+Beer+beer',
#  'Boss+Kozlak+Bock+beer',
#  'Bourbon+Barrel+Aged+Plead+The+5th+beer',
#  'Bourbon+County+Brand+Barleywine+Ale+beer',
#  'Bourbon+County+Brand+Coffee+Stout+beer',
#  'Bourbon+County+Brand+Stout+beer',
#  'Bourbon+County+Brand+Vanilla+Stout+beer',
#  'Bourbon+Paradise+beer',
#  'Boysenbeery+beer',
#  'Bracia+beer',
#  'Bran+Raven+beer',
#  'Bran+Reserva+beer',
#  'Brave+New+World+IPA+beer',
#  'Breakfast+Stout+beer',
#  'Brewers+Reserve+Barley+Wine+Aged+In+Bourbon+Barrels+beer',
#  'Brewfist++Prairie+Artisan+Ales++Spaghetti+Western+beer',
#  'Brewski+Mangofeber+DIPA+beer',
#  'Breznak+Schwarzbier+beer',
#  'Bridge+Road+Pale+Ale+beer',
#  'Britt+Rousse+beer',
#  'Brok+Export+beer',
#  'Brok+Sambor+Export+beer',
#  'Broken+Dream+beer',
#  'Brown+Ale+beer',
#  'Buckwheat+Ale+beer',
#  'Budweiser+Budvar+Czech+Dark+Lager+beer',
#  'Burly+Wine+beer',
#  'Buxton++Lervig++Trolltunga+beer',
#  'Buxton++Omnipollo++Yellow+Belly+beer',
#  'Buxton++Omnipollo+Yellow+Belly+Sundae+beer',
#  'Buxton++Stillwater++Subluminal+beer',
#  'By+Udder+Means+beer',
#  'Bötet+Barley+Wine+beer',
#  'Ctra+beer',
#  'CAmarillo+beer',
#  'CBS+Canadian+Breakfast+Stout+beer',
#  'Cable+Car+beer',
#  'Cabotella+beer',
#  'Cael++Crede+Ale+beer',
#  'Caramel+Fudge+Stout+beer',
#  'Castelain+Blond+Biere+De+Garde+beer',
#  'Celebration+Stout+beer',
#  'Celebrator+beer',
#  'Cervoise+Lancelot+beer',
#  'Chevalier+Saison+beer',
#  'Chili+Devil+beer',
#  'Chimera+beer',
#  'Chocolate+Rain+beer',
#  'Christmas+Ale+beer',
#  'Christoffel+Bier+beer',
#  'Chupacabras+Pale+Ale+beer',
#  'Citra+beer',
#  'Citra+Imperial+India+Pale+Ale+beer',
#  'Clout+Stout+beer',
#  'Clásica+Blonde+Ale+beer',
#  'Cocoa+Psycho+beer',
#  'Coedo+Kyara+beer',
#  'Coedo+Shikkoku+beer',
#  'Coedo+Shiro+beer',
#  'Coffee+Cinnamon+BBomb+beer',
#  'Coffee+Stout+beer',
#  'Coffee+Vanilla+Black+beer',
#  'Collective+Arts++Donut+Monster++Origin+of+Darkness+beer',
#  'Collective+Project+IPA+No+8+beer',
#  'Colorado+Appia+beer',
#  'Colorado+Berthô+beer',
#  'Colorado+Indica+beer',
#  'Colorado+Ithaca++Guanabara+beer',
#  'Colorado+Vixnu+beer',
#  'Columbus+beer',
#  'Columbus+Pils+beer',
#  'Contessa+beer',
#  'Copper+Coast+beer',
#  'Costa+Rica+Coffee+Porter+beer',
#  'Courage+Imperial+Russian+Stout+beer',
#  'Craftsman+beer',
#  'Crew+745+Escalation+beer',
#  'Crooked+Moon+Tattoo+beer',
#  'Crooked+Moon+Tattoo+Stockholm+beer',
#  'Cucapá+Barleywine+beer',
#  'Cuvee+Delphine+beer',
#  'Cuvee+Moeder+Kriek+beer',
#  'Cuvée+De+Ranke+beer',
#  'Cuvée+Des+Jacobins+Rouge+beer',
#  'Cuvée+Des+Jonquilles+beer',
#  'Cuvée+SaintGilloise+beer',
#  'Cuvée+Van+De+Keizer+Blauw+Blue+beer',
#  'Duva+Beer+beer',
#  'Dangerously+Close+To+Stupid+beer',
#  'Dark+Force+beer',
#  'Dark+Hops+beer',
#  'Dark+Island+beer',
#  'Dark+Island+Reserve+beer',
#  'Dark+Sky+Imperial+Stout+beer',
#  'Day+Of+The+Dead+Beer+Cerveza+De+Los+Muertos+Death+Becomes+You+beer',
#  'Day+Of+The+Dead+Beer+Cerveza+De+Los+Muertos+Immortal+Beloved+beer',
#  'Day+Of+The+Dead+Beer+Cerveza+De+Los+Muertos+Pay+The+Ferryman+beer',
#  'De+Prael+Barley+Wine+beer',
#  'Death+From+Above+beer',
#  'Debowe+Mocne+beer',
#  'Del+Ducato++Oxbow++Oud+Brunello+beer',
#  'Demon+beer',
#  'Demon+Hunter+beer',
#  'Dernière+Volonté+beer',
#  'Dernière+Volonté+Réserve+Spéciale+En+Fût+De+Pinot+Noir+beer',
#  'Digital+IPA+beer',
#  'Dinner+beer',
#  'Dobbel+Dose+Dobbel+Dram+beer',
#  'Dogma+74+beer',
#  'Dolii+Raptor+beer',
#  'Dominus+Vobiscum+Blanche+beer',
#  'Dominus+Vobiscum+Hibernus+beer',
#  'Dominus+Vobiscum+Lupulus+beer',
#  'Dominus+Vobiscum+Triple+beer',
#  'Don+De+Dieu+beer',
#  'Doppelbock+Dunkel+beer',
#  'Doppelbock+Grande+Cuvée+Printemps+beer',
#  'Doppelganger+beer',
#  'Double+Black+Mash+beer',
#  'Double+Citra®+beer',
#  'Double+Dry+Hopped+Congress+Street+beer',
#  'Double+Dry+Hopped+Fort+Point+Pale+Ale+beer',
#  'Double+Galaxy+beer',
#  'Double+Rye+IPA+beer',
#  'Double+Sunshine+beer',
#  'Doubleganger+beer',
#  'Draft+Bear+beer',
#  'Duchesse+De+Bourgogne+beer',
#  'Duchessic+Ale+beer',
#  'Duck+Duck+Gooze+beer',
#  'Dugges++Stillwater++Mango+Mango+Mango+beer',
#  'Dulcis+Succubus+beer',
#  'Duvel+Belgian+Golden+Ale+beer',
#  'Döllnitzer+Ritterguts+Gose+beer',
#  'E+B+Natural+Premium+Quality+Beer+beer',
#  'EB+Premium+beer',
#  'EKU+28+beer',
#  'ESB+beer',
#  'Eau+Benite+beer',
#  'Echigo+Stout+beer',
#  'Edelstoff+beer',
#  'Edelweiss+Dunkel+Weizenbier+beer',
#  'Edelweiss+Hefetrub+beer',
#  'Edelweiss+Weissbier+Hefetrüb+beer',
#  'Edelweiss+Weissbier+Snowfresh+beer',
#  'Eggenberg+Svetlý+Lezák+Premium+Lager+beer',
#  'Eisbock+beer',
#  'Eisenbahn+Escura+Dunkel+beer',
#  'Eisenbahn+Lust+beer',
#  'Eisenbahn+Pale+Ale+beer',
#  'Eisenbahn+Rauchbier+beer',
#  'Eisenbahn+Strong+Golden+Ale+beer',
#  'Eisenbahn+Vigorosa+Weizenbock+beer',
#  'Eisenbahn+Weizenbier+beer',
#  'Elemental+beer',
#  'Elizabethan+Ale+beer',
#  'Elvis+Juice+beer',
#  'Emelisse+Black+IPA+beer',
#  'Emelisse+Blond+beer',
#  'Emelisse+Imperial+Russian+Stout+beer',
#  'Emelisse+TIPA+beer',
#  'Emelisse+Winterbier+beer',
#  'Enkir+beer',
#  'Ephraim+beer',
#  'Epic+Armageddon+IPA+beer',
#  'Epic+Barrel+Aged+IPA+beer',
#  'Epic+Hop+Zombie+beer',
#  'Epic+Lager+beer',
#  'Epic+Larger+beer',
#  'Epic+Mayhem+beer',
#  'Epic+Pale+Ale+beer',
#  'Epicurean+Fig++Coffee+beer',
#  'Escorpion+Negro+beer',
#  'Ettaler+Curator+Dunkler+Doppelbock+US+Import+Version+beer',
#  'Export+India+Porter+beer',
#  'Export+Porter+1750+beer',
#  'Export+Stout+London+1890+beer',
#  'Extra+beer',
#  'Extra+Stout+beer',
#  'Extraomnes++Stillwater+Migdal+Bavel+beer',
#  'Fantôme+Saison+beer',
#  'Fat+Tug+IPA+beer',
#  'Fatamorgana+beer',
#  'Fatamorgana++Quadruple+DryHopped+beer',
#  'Faust+Hefeweizen+Dunkel+beer',
#  'Flagship+India+Pale+Ale+beer',
#  'FlandreKent+Les+Frères+De+La+Bière++Thiriez+XXtra+beer',
#  'Flat+White+Coffee+Milk+Stout+beer',
#  'Flora+Plum+beer',
#  'Flying+Monkeys+Acadian+Groove+Canadian+Maple+Porter+beer',
#  'Flying+Monkeys+The+Chocolate+Manifesto+beer',
#  'Focal+Banger+beer',
#  'Foggy+Geezer+beer',
#  'Forty+Four+American+Amber+beer',
#  'Forêt+Du+Centre+Light+Toasted+beer',
#  'Fou+Foune+beer',
#  'Four+Winds+IPA+beer',
#  'Fourth+Dementia++Bourbon+BarrelAged+beer',
#  'Framboise+Du+Fermier+beer',
#  'Framboos+beer',
#  'Franziskaner+HefeWeisse+beer',
#  'Franziskaner+Weissbier+Royal+beer',
#  'Fresh+Hopwired+beer',
#  'Fuck+Art++Lets+Dance+beer',
#  'Fullers+1845+beer',
#  'Fullers+ESB+beer',
#  'Fullers+London+Porter+beer',
#  'Fullers+London+Pride+beer',
#  'Fullers+Vintage+Ale+beer',
#  'Fundamental+Observation+beer',
#  'Fuzzy+beer',
#  'Fyr++Flamme+beer',
#  'Füchschen+Alt+beer',
#  'Galaxy+Dry+Hopped+Fort+Point+Pale+Ale+beer',
#  'Galaxy+Single+Hop+IPA+beer',
#  'Galway+Hooker+Irish+Pale+Ale+beer',
#  'Gavroche+beer',
#  'Geisterzug+Gose+Quinced+beer',
#  'Geisterzug+Gose+Rhubarb+beer',
#  'George+beer',
#  'Ghost+In+The+Machine++Double+DryHopped+beer',
#  'Gimbagagompa+Coffee+Vanilla+Granola+beer',
#  'Ginga+Kogen+Weizen+beer',
#  'Ginga+Kogen+Wheat+Beer+beer',
#  'Girardin+Gueuze+1882+Black+Label+beer',
#  'God+Jul+beer',
#  'Golden+Pride+beer',
#  'Golden+Tusk+beer',
#  'Goliat+beer',
#  'Gose+To+Hollywood+beer',
#  'Goudenband+beer',
#  'Grand+Cru+beer',
#  'Grand+Imperial+Porter+beer',
#  'Grand+Ridge+Moonshine+beer',
#  'Grande+Cuvée+Porter+Baltique+beer',
#  'Grande+Cuvée+Porter+Baltique++Fûts+De+Bourbon+Et+Brandy+beer',
#  'Grande+Negro+Voodoo+Papi++Bourbon+BarrelAged+beer',
#  'Grande+Noirceur+beer',
#  'Grande+Réserve+Blue+beer',
#  'Granitbock+beer',
#  'Granitbock+Ice+beer',
#  'Granát++BrouCzech+Dark+beer',
#  'Great+Lakes+Karma+Citra+IPA+beer',
#  'Great+Lakes+Lake+Effect+beer',
#  'Great+Lakes+Octopus+Wants+To+Fight+IPA+beer',
#  'Great+Lakes+Thrust+An+IPA+beer',
#  'Green+beer',
#  'Green+Card+Barleywine+beer',
#  'Gregorius+beer',
#  'Grieskirchner+Jörger+Weisse+beer',
#  'Grieskirchner+Pils+beer',
#  'Growler+American+Brown+Ale+beer',
#  'Gudeløs+beer',
#  'Gueuze+100+Lambic+beer',
#  'Gueuze+Tilquin+Draught+Version+beer',
#  'Guinness++Bulleit+BourbonAged+beer',
#  'Guinness+200th+Anniversary+Export+Stout+beer',
#  'Guinness+Extra+Stout+Original+beer',
#  'Guinness+Foreign+Extra+Stout+beer',
#  'Guinness+Milk+Stout+The+Brewers+Project+beer',
#  'Guinness+Original+beer',
#  'Guinness+Original+UK+Version++42+beer',
#  'Guinness+Special+Export+Stout++Antwerpen+Stout+beer',
#  'Gulden+Draak+beer',
#  'Gulpener+Dort+beer',
#  'Gulpener+Korenwolf+beer',
#  'Gunnamatta+beer',
#  'Gwiniz+Du+beer',
#  'Gösser+Dark+Beer+beer',
#  'HaandBic+beer',
#  'Haandbakk+beer',
#  'HackerPschorr+Dunkel+Weisse+Weisse+Dark+beer',
#  'HackerPschorr+Hefe+Weisse+Naturtrüb+beer',
#  'HackerPschorr+Oktoberfest+Märzen+beer',
#  'Halcyon+beer',
#  'Hallo+Ich+Bin+Berliner+Weisse++Raspberry+beer',
#  'Hamer++Sikkel+beer',
#  'Hardcore+IPA+beer',
#  'Hargreaves+Hill+Pale+beer',
#  'Harnas+beer',
#  'Harringtons+Big+John+Special+Reserve+beer',
#  'Harvest+Ale+Limited+Edition+beer',
#  'Harvest+Pale+Ale+beer',
#  'Havre+Stout+beer',
#  'Haze+beer',
#  'Hazy+Days+beer',
#  'Hazy+Jane+beer',
#  'Headroom+beer',
#  'Heady+Topper+beer',
#  'Heaven++Hell+beer',
#  'Hel++Verdoemenis+beer',
#  'Hel++Verdoemenis++Bourbon+BA+beer',
#  'Hel++Verdoemenis+Misto+BA+beer',
#  'Hel++Verdoemenis+Wild+Turkey+BA+beer',
#  'Heller+Bock+Saphir+beer',
#  'Helles+beer',
#  'Hellwoods+beer',
#  'Hemel++Aarde+beer',
#  'Herbe+à+Détourne+beer',
#  'Herold+Bohemian+Black+Lager+beer',
#  'Herold+Bohemian+Wheat+Lager+beer',
#  'Herold+Granat+beer',
#  'Hertog+Jan+Grand+Prestige+beer',
#  'Hesjeøl+beer',
#  'Hevelius+Kaper+beer',
#  'Hippy+Berliner+beer',
#  'Hirsch+BavarianWeissbier+Hefeweisse+beer',
#  'Hirter+1270+beer',
#  'Hirter+Morchl+beer',
#  'Hitachino+Nest+Amber+Ale+beer',
#  'Hitachino+Nest+Anbai+Ale+beer',
#  'Hitachino+Nest+Ancient+Nipponia+beer',
#  'Hitachino+Nest+Commemorative+Ale+beer',
#  'Hitachino+Nest+Dai+Dai+Ale+beer',
#  'Hitachino+Nest+Espresso+Stout+beer',
#  'Hitachino+Nest+Extra+High+XH+beer',
#  'Hitachino+Nest+Japanese+Classic+Ale+beer',
#  'Hitachino+Nest+Nipponia+beer',
#  'Hitachino+Nest+Pale+Ale+beer',
#  'Hitachino+Nest+Red+Rice+Ale+beer',
#  'Hitachino+Nest+Saison+Du+Japon+beer',
#  'Hitachino+Nest+Weizen+beer',
#  'Hitachino+Nest+White+Ale+beer',
#  'Hitachino+Nest+Yuzu+Lager+beer',
#  'Hofbräu+Münchner+Weisse+beer',
#  'Hommage+beer',
#  'Honey+beer',
#  'Hop++Liefde+beer',
#  'Hop+Hog+beer',
#  'Hopfenkönig+beer',
#  'Hopnotist+beer',
#  'Hoppy+Christmas+beer',
#  'Hopwired+beer',
#  'Horizon+Tokyo+Black+beer',
#  'Houblon+Chouffe+Dobbelen+IPA+Tripel+beer',
#  'Hr+Frederiksen+beer',
#  'Humulus+Ludicrous+beer',
#  'Hunahpus+Imperial+Stout+beer',
#  'Hunahpus+Imperial+Stout++Double+Barrel+Aged+beer',
#  'Hypnopompa+beer',
#  'I+Hardcore+You+beer',
#  'IIPA+Imperial+IPA+beer',
#  'IJndejaars+beer',
#  'IJwit+beer',
#  'IPA+beer',
#  'IPA+Citra+beer',
#  'IPA+Du+NordEst+beer',
#  'IPA+Samurai+beer',
#  'Idjit+beer',
#  'Immodest+beer',
#  'Immoralité+beer',
#  'Imper+Ale+Ubi+Rossa+beer',
#  'Imperial+Black+beer',
#  'Imperial+Brown+Ale+beer',
#  'Imperial+Brown+Stout+London+1856+beer',
#  'Imperial+IPA+beer',
#  'Imperial+India+Pale+Ale+500+beer',
#  'Imperial+Stout+beer',
#  'India+Pale+Ale+beer',
#  'Indian+Tribute+beer',
#  'Insurgente++Stone++Xocoveza+beer',
#  'Intense+Red+Oude+Kriek+beer',
#  'Iris+beer',
#  'Irish+Wheat+beer',
#  'Ise+Kadoya+Genmai+Ale+beer',
#  'Ise+Kadoya+IPA+beer',
#  'Ise+Kadoya+Imperial+Smoked+Porter+beer',
#  'It+Was+All+A+Dream+beer',
#  'Its+Alive++White+Wine+Barrel+Aged+beer',
#  'JW+Lees+Harvest+Ale+Calvados+Cask+beer',
#  'JW+Lees+Harvest+Ale+Lagavulin+Whisky+Cask+beer',
#  'JW+Lees+Harvest+Ale+Port+Cask+beer',
#  'JW+Lees+Harvest+Ale+Sherry+Cask+beer',
#  'JJJuliusss+beer',
#  'Jacobus+RPA+beer',
#  'Jade+Biere+Biologique+beer',
#  'Jaipur+IPA+beer',
#  'Jam+Up+the+Mash+beer',
#  'Jamieson+Beast+IPA+beer',
#  'Jelly+King+beer',
#  'Jenlain+Ambrée+beer',
#  'Jenlain+Or+beer',
#  'Jopen+Bokbier+beer',
#  'Jopen+Hoppenbier+beer',
#  'Jopen+Koyt+beer',
#  'Jopen+Northsea+IPA+beer',
#  'Jubilation+Ale+beer',
#  'Juice+Machine+beer',
#  'Jule+Mælk+beer',
#  'Julius+beer',
#  'Julius+Echter+HefeWeissbier+Hell+beer',
#  'Julöl+beer',
#  'Jutsu+beer',
#  'Juxtapose+Wild+IPA+beer',
#  'KBS+Kentucky+Breakfast+Stout+beer',
#  'Kaffestout+beer',
#  'Kaggen+Stormaktsporter+beer',
#  'Kapuziner+Weissbier+beer',
#  'Karpackie+Premium+beer',
#  'Kasteel+Barista+Chocolate+Quad+Belgian+Ale+beer',
#  'Kasteel+Winter+beer',
#  'Kasztelan+Unpasteurized+Niepasteryzowane+beer',
#  'Keene+Idea+beer',
#  'Kellerbier+UngespundetLager+hefetrüb+aU+Ungespundet+Naturtrüb+beer',
#  'Kentucky+Brunch+Brand+Stout+beer',
#  'King+Cobra+beer',
#  'King+JJJuliusss+beer',
#  'King+Julius+beer',
#  'King+Sue+beer',
#  'Kiper+Bock+beer',
#  'Kipling+beer',
#  'Klaster+Premium+beer',
#  'Klaster+Winter+Beer+beer',
#  'Klosterbräu+Schwärzla+beer',
#  'Knappstein+Reserve+Lager+beer',
#  'Knockmealdown+Porter+beer',
#  'Komes+Baltic+Porter+beer',
#  'Konrads+Stout+beer',
#  'Kooinda+Black+IPA++Full+Nelson+beer',
#  'Kopernik+beer',
#  'Koutská+12°+Dvanáctka+beer',
#  'Kozel+Cerny+Kozel+Dark+Velckopopovicky+beer',
#  'Kozlak+beer',
#  'Kramah+India+Pale+Ale+beer',
#  'Krampus+beer',
#  'Krekling+beer',
#  'Kremlin+Crude+beer',
#  'Kriek+100+Lambic+beer',
#  'Kriek+De+Ranke+beer',
#  'Krušovice+Mušketýr+beer',
#  'Kuri+Kuro+Dark+Chestnut+Ale+beer',
#  'Kurofune+Porter+beer',
#  'Kyritzer+Mord+Und+Totschlag+beer',
#  'Kávové+Pivo+beer',
#  'Kölsch+beer',
#  'LAmalthée+beer',
#  'LAmbrée+DEsquelbecq++Thiriez+Amber+beer',
#  'La+Blonde+D\x92Esquelbecq++Thiriez+Blonde+beer',
#  'La+Buteuse+beer',
#  'La+Buteuse+Brassin+Spécial+Barrel+Aged+beer',
#  'La+Chouffe+beer',
#  'La+Choulette+Ambrée+beer',
#  'La+Choulette+Blonde+beer',
#  'La+Choulette+De+Noël+beer',
#  'La+Choulette+Framboise+beer',
#  'La+Fin+Du+Monde+beer',
#  'La+Goudale+De+Noel+beer',
#  'La+Luna+Rossa+beer',
#  'La+Maline+beer',
#  'La+Migra+Imperial+Stout+beer',
#  'La+Mummia+beer',
#  'La+Rouge+Flamande+beer',
#  'La+Rousse+beer',
#  'La+Résolution+beer',
#  'La+Sirène+Saison+beer',
#  'La+Trappe+Bockbier+beer',
#  'La+Trappe+Isidor+beer',
#  'La+Trappe+Quadrupel+Koningshoeven++Dominus+beer',
#  'La+Trappe+Quadrupel++OakAged+beer',
#  'La+Trappe+Tripel+Koningshoeven++Dominus+beer',
#  'La+Trappe+Witte+Trappist+beer',
#  'La+Vache+Folle+Imperial+Milk+Stout+beer',
#  'Lambda+beer',
#  'Lambic+DAunis+beer',
#  'Lambic+Rhubarbe+beer',
#  'Lambiek+Special+beer',
#  'Landlord+Pale+Ale+beer',
#  'Last+Buffalo+In+The+Park+beer',
#  'Latus+beer',
#  'Lazurite+beer',
#  'Le+Temps+Noir+beer',
#  'Lech+Premium+beer',
#  'Leipziger+Gose+beer',
#  'Leon+beer',
#  'Lervig++Hoppin’+Frog+Sippin+Into+Darkness+beer',
#  'Lervig++Way+Beer++3+Bean+Stout+beer',
#  'Les+Bière+Des+Sans+Culottes+beer',
#  'Libertine+Black+Ale+beer',
#  'Life+in+the+Clouds+beer',
#  'Limfjordsporter+beer',
#  'Liquid+Confidential+beer',
#  'Liquid+Confidential+Cognac+Barrel+Aged+beer',
#  'Liquid+Confidential+WineSherry+Barrel+Aged+beer',
#  'Little+Creatures+Pale+Ale+beer',
#  'Lobkowicz+Baron+beer',
#  'Lobkowicz+Knight+beer',
#  'Lomza+Export+beer',
#  'Lomza+Mocne+beer',
#  'Lomza+Pelne+Premium+Beer+beer',
#  'London+Porter+beer',
#  'Lorelei+beer',
#  'Lou+Pepe++Framboise+beer',
#  'Lou+Pepe++Gueuze+beer',
#  'Lou+Pepe++Kriek+beer',
#  'Lustro+beer',
#  'MPA+beer',
#  'Macs+Hop+Rocker+Pilsener+beer',
#  'Mackaper+beer',
#  'Mackeson+Triple+XXX+Stout+beer',
#  'Mad+Abbot+Tripel+beer',
#  'Madamin+beer',
#  'Maelstrom+beer',
#  'Maledetta+beer',
#  'Maman+beer',
#  'Mamouche+beer',
#  'Manchester+Star+Ale+beer',
#  'Mannenliefde+beer',
#  'Marshmallow+Handjee+beer',
#  'Master+Polotmavý+13°+beer',
#  'Master+Tmavy+beer',
#  'Master+Tmavý+18°+beer',
#  'Mastodon+Mother+Puncher+beer',
#  'Maudite+beer',
#  'Maz+beer',
#  'Meinklang+Ancient+Grains+Ale+beer',
#  'Metalman+Pale+Ale+beer',
#  'Mexicali+Special+Dark+Beer+beer',
#  'Mexican+Brunch+beer',
#  'Mexican+Imperial+Stout+beer',
#  'Miami+Madness+beer',
#  'Mighty+Imperial+Ale+beer',
#  'Mikkeller++Grassroots+Wheat+Is+The+New+Hops+beer',
#  'Milk+Stout+beer',
#  'Mine+Is+Bigger+Than+Yours+beer',
#  'Minerva+Imperial+Tequila+Ale+beer',
#  'Minerva+Pale+Ale+beer',
#  'Minerva+Stout+beer',
#  'Minerva+Viena+beer',
#  'Minoh+WIPA+beer',
#  'Moa+5+Hop++Winter+Ale+beer',
#  'Moa+5+Hop+Ale+beer',
#  'Moa+Blanc+Evolution+beer',
#  'Moa+Imperial+Stout+Aged+In+Pinot+Noir+Barrels+beer',
#  'Moa+Methode+beer',
#  'Moa+Pale+Ale+beer',
#  'Moa+St+Josephs+beer',
#  'Modelo+Chelada+Limon+Y+Sal+beer',
#  'Modelo+Chelada+Tamarindo+Picante+beer',
#  'Moebius+beer',
#  'Moinette+Blond+beer',
#  'Momus+beer',
#  'Monks+Brew+beer',
#  'Mont+Des+Cats+Biere+Trappiste+beer',
#  'Monteiths+Barrel+Aged+Porter+beer',
#  'Monteiths+Doppelbock+beer',
#  'Monteiths+Doppelbock+Winter+Ale+beer',
#  'Mooi++Meedogenloos+beer',
#  'Moord++Doodslag++Disputin+beer',
#  'Moralité+beer',
#  'Mornin+Delight+beer',
#  'Morning+Wood+beer',
#  'Mornington+Peninsula+IPA+beer',
#  'Mornington+Peninsula+Pale+beer',
#  'Mosaic+Black+IPA+beer',
#  'Mosaic+Imperial+India+Pale+Ale+beer',
#  'Mountain+Goat+Fancy+Pants+Amber+Ale+beer',
#  'Mountain+Goat+Rye+IPA+beer',
#  'Mout++Mocca+beer',
#  'Murphys+Irish+Stout+beer',
#  'Murrays+Best+Extra+Porter+beer',
#  'Murrays+Heart+Of+Darkness+beer',
#  'Murrays+Icon+2IPA+beer',
#  'Murrays+Punch++Judy+beer',
#  'Murrays+Spartacus+beer',
#  'Murrays+Wild+Thing+Imperial+Stout+beer',
#  'Muscles+beer',
#  'My+Antonia+Birra+Del+Borgo++Dogfish+Head+beer',
#  'Mönchsambacher+Lager+beer',
#  'Mönchshof+Schwarzbier+beer',
#  'Mørke++Pumpernickel+Porter+beer',
#  'Mühlen+Kölsch+beer',
#  'NZ+Victory+Hop+Devil+IPA+beer',
#  'Nail+Stout+beer',
#  'Nath+beer',
#  'Natsumikan+Ale+beer',
#  'Naturtrüb+beer',
#  'Naughty+Hildegard+ESB+beer',
#  'Nautilus+beer',
#  'Nebuchadnezzar+beer',
#  'Nectarine+Premiere+beer',
#  'Nectarous+beer',
#  'Negra+Modelo+beer',
#  'Nelson+Sauvignon+Nelson+Sauvin+Brut+beer',
#  'Nelson+Sauvin+Single+Hop+IPA+beer',
#  'Neumarkter+Lammsbräu+Organic+Pilsner+beer',
#  'New+Town+11°+Light+Lager+beer',
#  'Nissefar+beer',
#  'Noche+Buena+beer',
#  'Nocturna+beer',
#  'Norwegian+Wood+beer',
#  'Not+Just+Another+Wit+beer',
#  'Notorious+Triple+IPA+beer',
#  'Noël+beer',
#  'Numazu+Lager+beer',
#  'Nuova+Mattina+beer',
#  'Nut+Brown+Ale+beer',
#  'Nøgne+Ø++Terrapin+Imperial+Rye+Porter+beer',
#  'OHaras+Barrel+Aged+Leann+Folláin+beer',
#  'OHaras+Irish+Stout+beer',
#  'OSheas+Traditional+Irish+Stout+beer',
#  'OK+Beer+beer',
#  'Oatmeal+Stout+beer',
#  'Obscura+American+Brown+Ale+beer',
#  'Odins+Tipple+beer',
#  'Oerbier+beer',
#  'Okocim+Zagloba+Premium+Beer+beer',
#  'Okocim+Beer+beer',
#  'Okocim+Jasne+Pelne+beer',
#  'Okocim+Mocne+beer',
#  'Okocim+Mocne+Premium+Malt+Liquor+beer',
#  'Ola+Dubh+Special+Reserve+12+beer',
#  'Ola+Dubh+Special+Reserve+16+beer',
#  'Ola+Dubh+Special+Reserve+18+beer',
#  'Ola+Dubh+Special+Reserve+21+beer',
#  'Ola+Dubh+Special+Reserve+30+beer',
#  'Ola+Dubh+Special+Reserve+40+beer',
#  'Old+Cellar+Dweller+beer',
#  'Old+Chimneys+Good+King+Henry+Imperial+Stout+beer',
#  'Old+Chimneys+Good+King+Henry+Special+Reserve+beer',
#  'Old+Engine+Oil+Black+Ale+beer',
#  'Old+Engine+Oil+Engineers+Reserve+Blackest+Ale+beer',
#  'Old+Kentucky+Bastard+beer',
#  'Old+Peculier+beer',
#  'Olde+Deuteronomy+beer',
#  'Olde+Suffolk+English+Strong+Suffolk+Vintage+Ale+beer',
#  'Oldgott+beer',
#  'Omnipollo++Buxton++Original+Rocky+Road+Ice+Cream+beer',
#  'Omnipollo++Buxton++Original+Texas+Pecan+Ice+Cream+beer',
#  'Omnipollo++Cervejaria+Tupiniquim++Polimango+beer',
#  'Omnipollo++Trillium++Covered+in+Puppies+beer',
#  'Onda+Mosaic+Pale+Ale+beer',
#  'Ongelovige+Thomas+beer',
#  'Organic+Chocolate+Stout+beer',
#  'Organic+Export+Scotch+Ale+beer',
#  'Original+Munchner+Hochzeitsbier+Von+1810+beer',
#  'Original+Schlüssel+Alt+beer',
#  'Orval+Trappist+Ale+beer',
#  'Ottakringer+Wiener+Original+beer',
#  'Oud+Beersel+Oude+Kriek+Vieille+beer',
#  'Oude+Gueuze+Tilquin²+beer',
#  'Oude+Geuze+beer',
#  'Oude+Geuze+Boon+Black+Label+beer',
#  'Oude+Geuze+Cuvée+Armand++Gaston+beer',
#  'Oude+Geuze+De+Cam+beer',
#  'Oude+Geuze+Golden+Blend+beer',
#  'Oude+Geuze+Vintage+beer',
#  'Oude+Gueuze+beer',
#  'Oude+Gueuze+Tilquin+à+LAncienne+beer',
#  'Oude+Kriek+beer',
#  'Oude+Kriek+De+Cam+beer',
#  'Oude+Lambiek+De+Cam+beer',
#  'Oude+Mûre+Tilquin+à+Lancienne+beer',
#  'Oude+Quetsche+Tilquin+à+LAncienne+beer',
#  'Oude+Quetsche+Tilquin+à+LAncienne+Avec+Prunes+De+Namur+beer',
#  'Oude+Schaarbeekse+Kriek+beer',
#  'Oyster+Stout+beer',
#  'Ozeno+Yukidoke+IPA+beer',
#  'PaasIJ+beer',
#  'Pacific+Ale+beer',
#  'Page+24+Biere+De+Printemps+beer',
#  'Page+24+Bière+De+Noël+beer',
#  'Page+24+Réserve+Hildegarde+beer',
#  'Page+24+Réserve+Hildegarde+Ambrée+beer',
#  'Pale+Ale+beer',
#  'Panil+Barriquée+Italy+Version+beer',
#  'Panil+Barriquée+Sour+Version+beer',
#  'Panil+Divina+beer',
#  'Pannepot+beer',
#  'Pannepot+Grand+Reserva+beer',
#  'Pannepot+Reserva+beer',
#  'Pannepøt++Old+Monks+Ale+beer',
#  'Parabola+beer',
#  'Paracelsus+Zwickl+beer',
#  'Passionfeber+IPA+beer',
#  'Patriot+beer',
#  'Peated+Imperial+Stout+beer',
#  'Perikles+Pilsner+beer',
#  'Perla+Chmielowa+Hop+Pearl+beer',
#  'Perla+Miodowa+Honey+beer',
#  'Perler+For+Svin+beer',
#  'Phaedra+beer',
#  'Pietra+De+Noel+beer',
#  'Pilsner+beer',
#  'Pinot+DAunis+beer',
#  'Plain+Porter+beer',
#  'Play+Dead+IPA+beer',
#  'Pleroma+beer',
#  'Pliny+The+Elder+beer',
#  'Pliny+The+Younger+beer',
#  'Podkovan+Dark+beer',
#  'Porter+beer',
#  'Porters+Rye+Ale+beer',
#  'Porterhouse+Red+beer',
#  'Pot+Kettle+Black+beer',
#  'Pothole+Filler+Imperial+Stout+beer',
#  'Potro+beer',
#  'Praga+Dark+Lager+beer',
#  'Premium+Lager++Kláster+Svetlý+Special+14+beer',
#  'Première+Red+beer',
#  'Primator+Dark+Lager+beer',
#  'Primátor+Maibock+beer',
#  'Primátor+Polotmavý+Märzen+beer',
#  'Primátor+Weizenbier+beer',
#  'Prior+8+beer',
#  'Prodromus+beer',
#  'Prunus+beer',
#  'Pseudo+Sue++Double+DryHopped+beer',
#  'Pszeniczniak+beer',
#  'Péché+Mortel+beer',
#  'Péché+Mortel++Bourbon+beer',
#  'Quarta+Runa+beer',
#  'Queen+Bohemian+Rhapsody+beer',
#  'RPA+Rye+Pale+Ale+beer',
#  'Radio+The+Mothership+beer',
#  'Raging+Flem+beer',
#  'Rain+Shadow+beer',
#  'Raised+By+Wolves+IPA+beer',
#  'Ransack+the+Universe+beer',
#  'Re+Ale+beer',
#  'Re+Ale+Extra+beer',
#  'Rebel+Red+beer',
#  'Red+Duck+Golden+Dragon+beer',
#  'Red+Duck+The+Ox+beer',
#  'Red+Fox+Rogues+American+Amber+beer',
#  'Red+Hill+Hop+Harvest+Ale+beer',
#  'Red+Hill+Imperial+Stout+beer',
#  'Red+Hill+Weizenbock+beer',
#  'Red+Pig+Mexican+Ale+beer',
#  'Red+Racer+IPA+India+Pale+Ale+beer',
#  'Red+Racer+Imperial+IPA+beer',
#  'Red+Rose+Amber+Ale+beer',
#  'Reparationsbajer+beer',
#  'Rewired+beer',
#  'Rieder+India+Pale+Ale+beer',
#  'Rieder+XXX+Weisse+beer',
#  'Riegele+Augustus+Weizendoppelbock+beer',
#  'Rince+Cochon+beer',
#  'Rising+Sun+Pale+Ale+beer',
#  'Road+Trip+beer',
#  'Rodenbach+Alexander+beer',
#  'Rodenbach+Caractère+Rouge+beer',
#  'Rodenbach+Grand+Cru+beer',
#  'Roman+Candle+beer',
#  'Rosé+De+Gambrinus+beer',
#  'Rothaus+Hefeweizen+beer',
#  'Rothaus+Pils+Tannen+Zäpfle+beer',
#  'Roundhouse+Kick+beer',
#  'Royal+Oak+Pale+Ale+beer',
#  'Rubus+beer',
#  'Rugporter+beer',
#  'Runaway+IPA+beer',
#  'Rycerskie+beer',
#  'Rökporter+beer',
#  'SR71+beer',
#  'Saint+Lamvinus+beer',
#  'Saint+Landelin+La+Divine+beer',
#  'Saint+Petersburg+Imperial+Stout+beer',
#  'Saint+Rieul+Triple+beer',
#  'Saint+Sylvesters+Flanders+Winter+Ale+beer',
#  'Saison+beer',
#  'Saison+Du+Fermier+beer',
#  'Saison+Dupont+beer',
#  'Saison+Sauvin+beer',
#  'Salvator+Doppel+Bock+beer',
#  'Samichlaus+Bier+Helles+beer',
#  'Samichlaus+Classic+Bier+beer',
#  'Samichlaus+Schwarzes+beer',
#  'Samson+Budweiser+Bier+Premium+beer',
#  'Samson+Budweiser+Bier+Černý+beer',
#  'Samurai+Barley+Ale+beer',
#  'Sant+Erwann+beer',
#  'Santas+Little+Helper+2012+beer',
#  'Sapporo+Premium+Black+Beer+beer',
#  'Sartori+Harvest+IPA+beer',
#  'Sassy+Red+beer',
#  'Schaerbeekse+Kriek+beer',
#  'Schlägl+BioRoggen+beer',
#  'Schlägl+Doppel+Bock+beer',
#  'Schlägl+Kristall+beer',
#  'Schlägl+Urquell+beer',
#  'Schneider+Aventinus+WeizenEisbock+beer',
#  'Schneider+Weisse+Tap+1+Mein+Blondes+beer',
#  'Schneider+Weisse+Tap+4+Wiesen+EdelWeisse+beer',
#  'Schneider+Weisse+Tap+5+Meine+Hopfenweisse+beer',
#  'Schneider+Weisse+Tap+6+Unser+Aventinus+beer',
#  'Schneider+Weisse+Tap+7+Unser+Original+beer',
#  'Schneider+Weisse+Tap+X+Aventinus+Cuvée+Barrique+beer',
#  'Schneider+Weisse+Tap+X+Mein+Nelson+Sauvin+beer',
#  'Schremser+Roggen+Bier+beer',
#  'Schumacher+Alt+beer',
#  'Schwarzbier+beer',
#  'Scottish+Stout+beer',
#  'Sedici+Gradi+beer',
#  'Seeing+Double+beer',
#  'Selassie++Coffee+And+Vanilla+Beans+beer',
#  'Seson+beer',
#  'Seventy+Seven+IPA+beer',
#  'Shiga+Kogen+IPA+beer',
#  'Shimaguni+Stout+beer',
#  'Shizuoka+Summer+Mikan+Ale+beer',
#  'Shoutao+Peach+Slush+IPA+beer',
#  'Simcoe+Single+Hop+IPA+beer',
#  'Single+Take+Session+Ale+beer',
#  'Singularity+beer',
#  'Sip+Of+Sunshine+beer',
#  'Siren++Cigar+City++Caribbean+Chocolate+Cake+beer',
#  'Skeleton+Key+beer',
#  'Skull+Splitter+beer',
#  'Skunkworks+Double+IPA+Cognac+Barrel+Aged+beer',
#  'Smithwicks+Winter+Spirit+beer',
#  'Snab+Pale+Ale+beer',
#  'Snow+Weizen+beer',
#  'Snowball+Saison+Ale+beer',
#  'Society++Solitude+4+beer',
#  'Society++Solitude+5+beer',
#  'Sol+Chelada+beer',
#  'Soleil+De+Minuit+beer',
#  'Solstice+Dhiver+Réserve+Spéciale+En+Fût+De+Bourbon+beer',
#  'Solstice+Dété+Aux+Framboises+beer',
#  'Sort+Mælk+beer',
#  'Southwark+Old+Stout+beer',
#  'Sovereign+Super+Saison+beer',
#  'Spaceman+beer',
#  'Spaghetti+Western++Grappa+BarrelAged+beer',
#  'Spanning++Sensatie+beer',
#  'Spaten+Optimator+beer',
#  'Special+Holiday+Ale++Nøgne+ØJolly+Pumpkin+Artisan+AlesStone+Brewing+Co+beer',
#  'Speedway+Stout++Vietnamese+Coffee++BourbonBarrel+Aged+beer',
#  'Speights+Old+Dark+beer',
#  'Spezial+Rauchbier+Märzen+beer',
#  'Spildt+Mælk+Boys+Don’t+Cry+Over+Spilled+Milk+beer',
#  'SpontanCherryFrederiksdal+beer',
#  'SpontanSeabuckthorn+beer',
#  'Spontanbeetroot+beer',
#  'Spontancassis+beer',
#  'Spontandryhop+Citra+beer',
#  'Spontanframboos+beer',
#  'Spontansauternes+beer',
#  'StAmbroise+Oatmeal+Stout+beer',
#  'StAmbroise+Stout+Impériale+Russe+beer',
#  'St+Amand+beer',
#  'St+Amatus+12+beer',
#  'St+Martin+Dunkler+Doppelbock+beer',
#  'Staropolskie+Mocne+beer',
#  'Staropramen+Velvet+beer',
#  'Staropramen+Černý+beer',
#  'Stateside+IPA+beer',
#  ...]

# %%
Test.BeerCrawling()
# Out:
#  100.png
# 1812.png
# 19.png
# 3 Monts Amber Ale On Lees.png
# 3 Monts Flanders Golden Ale.png
# 4 Pines Dry Stout.png
# 90 Wee Heavy.png
# APA.png
# Aaron.png
# Aass Bayer Aass Dark.png
# Aass Bock.png
# Aass Genuine Pilsner.png
# Aass Juleøl.png
# Abbaye Des Rocs Grand Cru Belgian Special Brown.png
# Abbaye Des Rocs Brasserie Des Rocs Brune.png
# Abrahadabra.png
# Abricot Du Fermier.png
# Abt 12.png
# Abt 12 Oak Aged.png
# Ace Of Spades.png
# Achel Trappist Extra.png
# Adnams TallyHo.png
# Aecht Schlenkerla Eiche.png
# Aecht Schlenkerla Fastenbier.png
# Aecht Schlenkerla Helles Lagerbier.png
# Aecht Schlenkerla Kräusen.png
# Aecht Schlenkerla Rauchbier Märzen.png
# Aecht Schlenkerla Rauchbier Urbock.png
# Aecht Schlenkerla Rauchbier Weizen.png
# Agamemnon.png
# Agent Provocateur.png
# Akevitt.png
# AlIksir.png
# Ale Gâteau ForêtNoire.png
# Alpha Pale Ale.png
# Altbier.png
# Alter Ego.png
# Amager  Grassroots  Shadow Pictures  Skyggebilleder.png
# Amager  Jester King  Danish Metal.png
# Amager  Mikkeller  Hr Frederiksens Væsel Brunch.png
# Amager  Mikkeller  Hr Frederiksens Væsel Brunch  BarrelAged.png
# Amager  Surly  Todd The Axe Man.png
# Amarillo.png
# Tuatara Porter.png
# Tuatara Weiz Guy.png
# Tucher Bajuvator Doppelbock.png
# Tucher Helles Hefe Weizen.png
# Twenty Pounder.png
# Two Captains.png
# Tyskie Gronie.png
# U Fleku Dark Lager.png
# USAlive Alive.png
# Uerige Doppelsticke.png
# Uerige Sticke.png
# Underlig Jul.png
# Unibroue 17 Grande Réserve.png
# Urbock 23°.png
# VSOJ.png
# Valsviken Vinterporter.png
# Verdi Imperial Stout.png
# Very GGGreennn.png
# Very Green.png
# Very Hazy.png
# ViaEmilia.png
# Vieille Brune.png
# Vigneronne.png
# Villacher Märzen.png
# Vivat Triple.png
# Voyager.png
# Vuur  Vlam.png
# Wals Petroleum.png
# Warka.png
# Warka Premium Strong.png
# Warka Radler Lemonade.png
# Watermelon Warhead.png
# Wee Heavy.png
# Weihenstephaner  Sierra Nevada  Braupakt.png
# Weihenstephaner 1516 Kellerbier.png
# Weihenstephaner Hefeweissbier.png
# Weihenstephaner Hefeweissbier Dunkel.png
# Weihenstephaner Korbinian.png
# Weihenstephaner Kristallweissbier.png
# Weihenstephaner Original.png
# Weihenstephaner Vitus.png
# Weisse Whitebeer.png
# Weltenburger Kloster AsamBock.png
# Weltenburger Kloster Barock Dunkel.png
# West Ashley.png
# West Coast IPA.png
# West Indies Porter.png
# Westly.png
# Westmalle Trappist Dubbel.png
# Westmalle Trappist Tripel.png
# White Crane Ale Rogues Oregon Golden Ale.png
# Wild Raven.png
# Wildebeest.png
# Winterlude.png
# Wit.png
# Witchshark.png
# Wrasslers XXXX Stout.png
# Wäls Quadruppel.png
# XBeer 33.png
# XRay.png
# Xyauyù Barrel.png
# Xyauyù Etichetta Oro Gold.png
# Xyauyù Fumé Islay Whisky.png
# YabaiYabai Strong Scotch Ale.png
# Yakima IPA.png
# Yebisu Black Beer.png
# Yeti.png
# Yona Yona Ale.png
# Yorkshire Stingo.png
# Youngs Double Chocolate Stout.png
# Youngs Special London Ale.png
# Zamkowe.png
# Zamkowe Dark.png
# Zamkowe Jasne.png
# Zatte.png
# Zenne Y Frontera.png
# Zipfer Urtyp.png
# Zodiak.png
# Zombie Dust.png
# Zona Cesarini.png
# Zubr.png
# Zundert 8.png
# Zywiec Bock.png
# iStout.png
# xeRRex.png
# §ucaba.png
# Ægir India Pale Ale.png
# Örebro Bitter.png
# Łomża Wyborowe.png
# Štěpán  český Klasický Ležák Světlý.png
# 전체 맥주의 수:  1176
#
# 수집된 맥주의 수:  0
#
# 에러가 난 맥주의 수:  1176
#
# 0? 0
#
#  Error List:
#  ['+100+beer', '1812+beer', '19+beer', '3+Monts+Amber+Ale+On+Lees+beer', '3+Monts+Flanders+Golden+Ale+beer', '4+Pines+Dry+Stout+beer', '90+Wee+Heavy+beer', 'APA+beer', 'Aaron+beer', 'Aass+Bayer+Aass+Dark+beer', 'Aass+Bock+beer', 'Aass+Genuine+Pilsner+beer', 'Aass+Juleøl+beer', 'Abbaye+Des+Rocs+Grand+Cru+Belgian+Special+Brown+beer', 'Abbaye+Des+Rocs+Brasserie+Des+
Aged+Abraxas+beer', 'Beamish+Irish+Stout+beer', 'Beatification+beer', 'Bedarö+Bitter+beer', 'Beer+Geek+Breakfast+beer', 'Beer+Geek+Brunch+Weasel+beer', 'Beer+Geek+Brunch+Weasel+Bourbon+Edition+beer', 'Beer+Geek+Brunch+Weasel+Islay+Edition+beer', 'Beer+Geek+Brunch+Weasel++Cognac+Edition+beer', 'Beer+Geek+Cocoa+Shake+beer', 'Beer+Geek+Dessert+beer', 'Beer+Geek+Vanilla+Maple+Shake+beer', 'Beer+Geek+Vanilla+Shake+beer', 'Beer+Geek+Vanilla+Shake++Bourbon+BarrelAged+beer', 'Beer+Hop+Breakfast+beer', 'BeerBarrelTime+beer', 'BeerBera+beer', 'Beersel+Mattina+beer', 'Beglo+beer', 'Bellerose+Biere+Blonde+Extra+beer', 'Belô+Petroleum+beer', 'Benno+beer', 'Bernard+Bohemian+Ale+beer', 'Bernard+Cerne+Dark+beer', 'Best+Extra+Stout+beer', 'Bestefar+beer', 'Beyond+Good+And+Evil+beer', 'Bianca+beer', 'Bianca+Mango+Lassi+Gose+beer', 'Biere+Aux+Marrons+beer', 'Biere+DAbbaye+Lacu+beer', 'Big+Worster+beer', 'Bishops+Farewell+beer', 'Bière+De+Noël+beer', 'Bière+Nouvelle+beer', 'Black+Albert+beer', 'Black+Ball+Porter+beer', 'Black+Betty+beer', 'Black+Boss+Porter+beer', 'Black+Damnation+II++Mocha+Bomb+beer', 'Black+Damnation+V++Double+Black+beer', 'Black+Gold+beer', 'Black+Magic+Woman+beer', 'Black+Malts+And+Body+Salts+beer', 'Black+Note+Stout+beer', 'Black+Oak+Ten+Bitter+Years+beer', 'Black+Shark+beer', 'Black+Tokyo+Horizon+beer', 'Blac ...

# %%
len(['Aass+Bayer+Aass+Dark+beer',
 'Ale+Gâteau+ForêtNoire+beer',
 'Ayinger+UrWeisse+beer',
 'Beatification+beer',
 'Black+Damnation+II++Mocha+Bomb+beer',
 'Colorado+Appia+beer',
 'Cuvee+Delphine+beer',
 'Cuvée+Des+Jonquilles+beer',
 'Day+Of+The+Dead+Beer+Cerveza+De+Los+Muertos+Death+Becomes+You+beer', 
 'Day+Of+The+Dead+Beer+Cerveza+De+Los+Muertos+Pay+The+Ferryman+beer',
 'Dugges++Stillwater++Mango+Mango+Mango+beer',
 'Extra+beer',
 'Fuck+Art++Lets+Dance+beer',
 'God+Jul+beer',
 'Granát++BrouCzech+Dark+beer',
 'Hel++Verdoemenis+Misto+BA+beer',
 'Hirter+1270+beer',
 'Hirter+Morchl+beer',
 'Hitachino+Nest+Yuzu+Lager+beer',
 'Imperial+Brown+Ale+beer',
 'LAmalthée+beer',
 'Maelstrom+beer', 
 'Mooi++Meedogenloos+beer',
 'Ola+Dubh+Special+Reserve+16+beer',
 'Old+Chimneys+Good+King+Henry+Imperial+Stout+beer',
 'Stifter+Bier+Red+Ale+beer',
 'Sunday+Brunch+beer', 'Tak+Pale+Ale+beer', 'Tuatara+Helluva+beer'])
# Out:
# 29

# %%
1148 + 28
# Out:
# 1176
