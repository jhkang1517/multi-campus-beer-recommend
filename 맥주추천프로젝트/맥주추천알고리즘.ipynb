# %%
import pickle
with open('BeerVer5.pkl', 'rb') as f:
    data = pickle.load(f)
data.head()
# Out:
#                                             feel  \
# 0      {'medium': 89, 'creamy': 54, 'light': 48}
# 1  {'medium': 227, 'smooth': 124, 'creamy': 108}
# 2       {'medium': 43, 'smooth': 35, 'full': 27}
# 3         {'thick': 2, 'creamy': 2, 'medium': 2}
# 4         {'medium': 14, 'smooth': 8, 'full': 8}
#
#                                        look                       name  \
# 0  {'hazy': 84, 'cloudy': 74, 'golden': 71}         Ayinger Weizenbock
# 1  {'brown': 331, 'dark': 230, 'light': 83}                    Prior 8
# 2     {'brown': 82, 'dark': 57, 'deep': 26}  Pannepøt - Old Monk's Ale
# 3     {'golden': 2, 'cloudy': 2, 'gold': 2}       Bridge Road Pale Ale
# 4    {'brown': 21, 'dark': 17, 'coffee': 7}             Kasteel Winter
#
#                                          smell  \
# 0  {'banana': 209, 'clove': 150, 'wheat': 125}
# 1    {'fruit': 340, 'dark': 311, 'sweet': 246}
# 2       {'dark': 101, 'fruit': 93, 'malt': 54}
# 3    {'hop': 11, 'citrus': 7, 'grapefruit': 5}
# 4  {'coffee': 23, 'dark': 17, 'chocolate': 13}
#
#                                         taste
# 0   {'banana': 130, 'wheat': 83, 'clove': 77}
# 1    {'fruit': 175, 'malt': 169, 'dark': 166}
# 2    {'dark': 46, 'fruit': 45, 'caramel': 31}
# 3    {'hop': 6, 'citrus': 5, 'grapefruit': 3}
# 4  {'coffee': 13, 'chocolate': 11, 'dark': 6}

# %% [markdown]
# # Python3 코드

# %%
import operator
def recommand(*args, data = data):    
    # 각 feature별 리스트 생성
    feel = []
    look = []
    taste = []
    smell = []
    # 각 feature의 값들은 리뷰의 카운트 / 전체 카운트 값을 가중치로
    # 모든 feature의 가줓이는 하나의 딕셔너리에
    # key = 해당 feature의 명칭, value 가중치 값
    new_dict = {}
    for arg in args:
        for feature in ['feel', 'look', 'taste', 'smell']:
            data_f = data[data['name'] == arg][feature].values[0]
            for key in data_f.keys():
                if key in new_dict.keys():
                    new_dict[key] = new_dict[key] + ( data_f[key] / sum(data_f.values()) )
                else:
                    new_dict[key] = (data_f[key] / sum(data_f.values()))
    
    result_dict = {}
    for j in range(len(data)):
        value = 0
        for feature in ['feel', 'look', 'taste', 'smell']:
            data_t = data.loc[j][feature]
            name = data.loc[j]['name']
            for key in data_t:
                if key in new_dict.keys():
                    value += new_dict[key] * data_t[key] / sum(data_t.values()) 

        result_dict[name] = value

    
    # max_값 찾기(3개 출력)
    a_list =  sorted(result_dict.items(), key=operator.itemgetter(1), reverse=True)
    
    result = []
    cnt = 0
    while cnt != 3:
        beer = a_list.pop(0)[0]
        if beer not in args:
            cnt += 1
            result.append([cnt, beer])
    return result

# %%
a = 'Muscles'
b = 'Zywiec Bock'
c = 'Okocim Mocne'
test = recommand(a, c)

# %%
test
# Out:
# [[1, 'Lomza Mocne'], [2, 'Zamkowe'], [3, 'Boss Beer']]

# %%
list(data['name'])
# Out:
# ['Ayinger Weizenbock',
#  'Prior 8',
#  "Pannepøt - Old Monk's Ale",
#  'Bridge Road Pale Ale',
#  'Kasteel Winter',
#  'Urbock 23°',
#  'Praga Dark Lager',
#  "Malt's Beer",
#  'Jopen Hoppenbier',
#  'Emelisse TIPA',
#  'IPA Samurai',
#  'Klaster Premium',
#  'Zywiec Bock',
#  'De Prael Barley Wine',
#  'Okocim Jasne Pelne',
#  'Hevelius Kaper',
#  'Agamemnon',
#  'Aon Pecan Mud Cake - Bourbon Barrel-Aged',
#  'Perikles Pilsner',
#  'Shoutao Peach Slush IPA',
#  'Muscles',
#  'Bedarö Bitter',
#  'Valsviken Vinterporter',
#  'Julöl',
#  'Abrahadabra',
#  'Coffee Stout',
#  'Baronen',
#  'Mackaper',
#  'Brush',
#  'Imperial Stout',
#  'Leon',
#  'Passionfeber IPA',
#  'Örebro Bitter',
#  'CAmarillo',
#  'Bergsmansöl',
#  'Sigtuna Midvinterblot (2012 - )',
#  'Indian Tribute',
#  'Rökporter',
#  'Beglo',
#  'Bötet Barley Wine',
#  'Amarillo',
#  'Prodromus',
#  'Aniara',
#  'Omnipollo / Cervejaria Tupiniquim - Polimango',
#  'Onda Mosaic Pale Ale',
#  'Aurora',
#  'Omnipollo / Buxton - Original Rocky Road Ice Cream',
#  'Maz',
#  'West Coast IPA',
#  'Magic #4:21 Raspberry Smoothie IPA',
#  'Idjit!',
#  'Symzonia',
#  'Hypnopompa - Rum Barrel-Aged',
#  'Gimbagagompa Coffee Vanilla Granola',
#  'Coffee Vanilla Black',
#  'Hypnopompa',
#  'Dugges / Stillwater - Mango Mango Mango',
#  'Nautilus',
#  'Lustro',
#  'Amazing Haze',
#  'Bianca Mango Lassi Gose',
#  'Moebius',
#  'Lorelei',
#  'Brewski Mangofeber DIPA',
#  'Fatamorgana - Quadruple Dry-Hopped',
#  'Dugges / Stillwater - Speyside Cacao',
#  'Selassie - Coffee And Vanilla Beans',
#  'Omnipollo / Buxton - Original Texas Pecan Ice Cream',
#  'Pleroma',
#  'Hilma',
#  'Zodiak',
#  'Carnegie Porter 5,5%',
#  'Fatamorgana',
#  'Stillwater / Dugges - Tropic Punch Ale',
#  'Aon Pecan Mud Cake',
#  'Kaggen! Stormaktsporter',
#  'Nebuchadnezzar',
#  'Omnipollo / Trillium - Covered in Puppies',
#  'Boss Beer',
#  'Tyskie Gronie',
#  'Okocim Mocne',
#  'Harnas',
#  'Okocim Beer',
#  'Tatra',
#  'Warka',
#  'EB Premium',
#  'Karpackie Super',
#  'Tatra Mocne',
#  'Lomza Pelne (Premium Beer)',
#  'Lomza Mocne',
#  'Lomza Export',
#  'Brok Export',
#  'Karpackie Premium',
#  'Łomża Wyborowe',
#  'Lech Premium',
#  'Zamkowe',
#  'Warka Premium (Strong)',
#  'Brok Sambor Export',
#  'Kasztelan Unpasteurized (Niepasteryzowane)',
#  'Debowe Mocne',
#  'E B Natural Premium Quality Beer',
#  'Zubr',
#  'Kopernik',
#  'Kiper Pils',
#  'Van Pur Premium',
#  'O.K. Beer',
#  'Okocim Mocne Premium Malt Liquor',
#  'Perla Chmielowa (Hop Pearl)',
#  'Okocim (Zagloba) Premium Beer',
#  'Zamkowe Jasne',
#  'Zamkowe Dark',
#  'King Cobra',
#  'Rycerskie',
#  'Czarny Boss Porter 18,1% Wag.',
#  'Żywiec APA',
#  'Staropolskie Mocne',
#  'Kiper Bock',
#  'Pszeniczniak',
#  'Perla Miodowa (Honey)',
#  'Kozlak',
#  'Warka Radler (Lemonade)',
#  'Boss Kozlak (Bock)',
#  'Grand Imperial Porter',
#  'Piwo Z Grodziska',
#  'Black Boss Porter',
#  'Porter',
#  'Komes Baltic Porter',
#  'Hamer & Sikkel',
#  'Jacobus RPA',
#  'Lentehop',
#  'Gulpener Dort',
#  'Emelisse Blond',
#  'Jopen Bokbier',
#  'Jopen Lentebier',
#  'De Prael Tripel',
#  'PaasIJ',
#  'IJndejaars',
#  'Emelisse Winterbier',
#  'Mannenliefde',
#  'Zatte',
#  'Storm & Bliksem (Amarillo)',
#  'La Trappe Witte Trappist',
#  'Christoffel Bier',
#  'IJwit',
#  'Gulpener Korenwolf',
#  'Emelisse Black IPA',
#  'IPA',
#  'Columbus',
#  'Maelstrom',
#  'Hop & Liefde',
#  'Double Rye IPA',
#  'Vuur & Vlam',
#  'Snab Pale Ale',
#  'Zundert 8',
#  'Bloed, Zweet & Tranen',
#  'Struis',
#  'Jopen Northsea IPA',
#  'American Barley Wine',
#  'Peated Imperial Stout',
#  'Hertog Jan Grand Prestige',
#  'Bommen & Granaten',
#  'Jopen Koyt',
#  'La Trappe Dubbel (Koningshoeven / Dominus)',
#  'Moord & Doodslag - Disputin',
#  'Mout & Mocca',
#  'Emelisse Imperial Russian Stout',
#  'Mooi & Meedogenloos',
#  'La Trappe Tripel (Koningshoeven / Dominus)',
#  'Ongelovige Thomas',
#  'Hemel & Aarde',
#  'Heaven & Hell',
#  "La Trappe Isid'or",
#  'La Trappe Bockbier',
#  'Spanning & Sensatie',
#  'Export Porter 1750',
#  'Caramel Fudge Stout',
#  'Tsarina Esra',
#  'Hel & Verdoemenis Misto B.A.',
#  'Hel & Verdoemenis',
#  'La Trappe Quadrupel (Koningshoeven / Dominus)',
#  'Bianca',
#  'Hel & Verdoemenis Wild Turkey B.A.',
#  'Hel & Verdoemenis - Bourbon BA',
#  'Elixir',
#  'Momus',
#  'Maledetta',
#  "Biere D'Abbaye Lacu",
#  'Spaceman',
#  'Baluba',
#  'X-Ray',
#  'Enkir',
#  'Bibock',
#  'Tre Fontane Tripel',
#  'Bran Reserva',
#  'Panil Divina',
#  'Bran Raven',
#  'Krampus',
#  'Dolii Raptor',
#  'Madamin',
#  "D'uva Beer",
#  'La Trappe Quadrupel - Oak-Aged',
#  'Imper Ale Ubi Rossa',
#  'Machete',
#  'BB Dexi',
#  'ViaEmilia',
#  'Chimera',
#  'Toccalmatto / Prairie - Okie Matilda',
#  'La Mummia',
#  'Re Ale',
#  'Demon Hunter',
#  'Brett Peat Daydream',
#  'BB10',
#  'Al-Iksir',
#  'Super',
#  'Winterlude',
#  'Seson',
#  'Rubus',
#  'Nuova Mattina',
#  'Re Ale Extra',
#  'Contessa',
#  'Noël',
#  'Prunus',
#  'BeerBera',
#  'Vùdù',
#  'Tipopils',
#  "Thomas Hardy's Ale (2015 -)",
#  'Quarta Runa',
#  'Spaghetti Western - Grappa Barrel-Aged',
#  'Extraomnes / Stillwater Migdal Bavel',
#  'Sedici Gradi',
#  'Zona Cesarini',
#  'Brewfist / Prairie Artisan Ales - Spaghetti Western',
#  'Panil Barriquée (Sour Version)',
#  'Verdi Imperial Stout',
#  'Day Of The Dead Beer (Cerveza De Los Muertos) Death Becomes You',
#  'Del Ducato / Oxbow - Oud Brunello',
#  'Potro',
#  'Negra Modelo',
#  'Day Of The Dead Beer (Cerveza De Los Muertos) Immortal Beloved',
#  'Red Pig Mexican Ale',
#  'Tecate Titanium (7.5%)',
#  'Cabotella',
#  'Noche Buena',
#  'Bohemia Clásica',
#  'Chili Devil',
#  'Tijuana Güera',
#  'Bohemia Weizen',
#  'Bohemia Oscura',
#  'Day Of The Dead Beer (Cerveza De Los Muertos) Pay The Ferryman',
#  'Honey',
#  'Mexicali Special Dark Beer',
#  'Tecate Michelada Diablo',
#  'Chupacabras Pale Ale',
#  'Dos Equis Invierno Winter Bock',
#  'La Luna Rossa',
#  'Baladin Nora',
#  'My Antonia (Birra Del Borgo & Dogfish Head)',
#  'Duchessic Ale',
#  'Xyauyù Fumé (Islay Whisky)',
#  'Xyauyù Etichetta Oro (Gold)',
#  'Baciami Lipsia (Kiss My Lips)',
#  'Panil Barriquée (Italy Version)',
#  'Beersel Mattina',
#  'BeerBrugna',
#  'Xyauyù Barrel',
#  'Obscura American Brown Ale',
#  'Modelo Chelada Tamarindo Picante',
#  'Minerva Colonial',
#  'Minerva Pale Ale',
#  'TJ Tijuana Mexican Lager',
#  'Tijuana Morena',
#  'Minerva Viena',
#  'Clásica Blonde Ale',
#  'Modelo Chelada Limon Y Sal',
#  'Tempus Clasica',
#  'Escorpion Negro',
#  'Minerva Imperial Tequila Ale',
#  'La Migra Imperial Stout',
#  'Runaway IPA',
#  'Sol Chelada',
#  'Green Card Barleywine',
#  'Britt Rousse',
#  'Jenlain Or',
#  'Vieille Brune',
#  'Rince Cochon',
#  'Pietra De Noel',
#  "Ch'ti Blanche",
#  'Yeti',
#  'Jade (Biere Biologique)',
#  'Biere Aux Marrons',
#  'Vivat Triple',
#  "Brassin D'Hiver",
#  'La Maline',
#  'La Choulette Blonde',
#  'Anosteke',
#  'Bière De Noël',
#  'La Wambrechies',
#  'Page 24 Réserve Hildegarde Ambrée',
#  'Etoile Du Nord',
#  'Sant Erwann',
#  'Tempus Doble Malta',
#  'Minerva Stout',
#  'Cucapá Barleywine',
#  'Mexican Imperial Stout',
#  'Nocturna',
#  'La Lupulosa',
#  'Insurgente / Stone - Xocoveza',
#  'Gwiniz Du',
#  'Saint Landelin La Divine',
#  'Grand Cru',
#  'Jenlain Ambrée',
#  "Grain D'Orge",
#  'Bière Nouvelle',
#  'Mont Des Cats Biere Trappiste',
#  'Angelus',
#  'La Petite Princesse',
#  'Page 24 Réserve Hildegarde',
#  'La Goudale De Noel',
#  "Saint Sylvester's Flander's Winter Ale",
#  'St. Amand',
#  'Agent Provocateur',
#  'Telenn Du',
#  'La Rousse',
#  'Page 24 Bière De Noël',
#  'La Rouge Flamande',
#  'Gavroche',
#  'La Choulette De Noël',
#  'Bellerose Biere Blonde Extra',
#  'Train To Mars',
#  'Page 24 Biere De Printemps',
#  "L'Ambrée D'Esquelbecq / Thiriez Amber",
#  'XI.I',
#  'Castelain Blond Biere De Garde',
#  'La Choulette Framboise',
#  'Cervoise Lancelot',
#  'La Choulette Ambrée',
#  'Extra',
#  'Saint Rieul Triple',
#  '3 Monts Flanders Golden Ale',
#  "La Blonde D'\x92Esquelbecq / Thiriez Blonde",
#  "L'Amalthée",
#  '3 Monts Amber Ale On Lees',
#  'Flandre-Kent Les Frères De La Bière / Thiriez XXtra',
#  'Cuvée Des Jonquilles',
#  'Les Bière Des Sans Culottes',
#  'Herold Granat',
#  'Queen Bohemian Rhapsody',
#  'Breznak Schwarzbier',
#  'X-Beer 33',
#  'Samson Budweiser Bier Premium',
#  'Demon',
#  'Konrad Jocker Svìtlý Le\x9eák 14°',
#  'Primator Dark Lager',
#  'Krušovice Mušketýr',
#  'Primátor Maibock',
#  'Oldgott',
#  'Samson Budweiser Bier Černý',
#  'Master Polotmavý 13°',
#  'Lobkowicz Baron',
#  'Svijanský Máz 11%',
#  'Staropramen Černý',
#  'Budweiser Budvar Czech Dark Lager',
#  'Staropramen Velvet',
#  'Kozel Cerny (Kozel Dark) Velckopopovicky',
#  'Lobkowicz Knight',
#  'Granát - BrouCzech Dark',
#  'Lobkowicz Prince',
#  'Podkovan Dark',
#  'Dark Lager (Tmavý Le\x9eák)',
#  'Klaster Winter Beer',
#  'Primátor Polotmavý Märzen',
#  'New Town 11° Light Lager',
#  'Herold Bohemian Wheat Lager',
#  'Bernard Cerne (Dark)',
#  'Svijanská Kněžna 13%',
#  '\x8eŽatec Dark Lager',
#  'Eggenberg Svetlý Lezák (Premium Lager)',
#  'Kávové Pivo',
#  'Primátor Weizenbier',
#  'Štěpán - český Klasický Ležák Světlý',
#  'Premium Lager / Kláster Svetlý Special 14%',
#  'Staropramen Kelt Original Stout',
#  'Master Tmavy',
#  'Bernard Bohemian Ale',
#  'Porter Boom',
#  'Master Tmavý 18°',
#  'Herold Bohemian Black Lager',
#  'Pilsner Urquell Nefiltrovaný',
#  'Koutská 12° Dvanáctka',
#  'U Fleku Dark Lager',
#  'Tuatara Ardenne',
#  'Boysenbeery',
#  'Invercargill Pitch Black Black Beer',
#  'Golden Tusk',
#  'Voyager',
#  'Moa 5 Hop Ale',
#  'Enlightenment Great Punkin',
#  'The Rogue Hop',
#  'Tuatara Weiz Guy',
#  'Tuatara Helluva',
#  'Mighty Imperial Ale',
#  "Monteith's Doppelbock",
#  'Moa Blanc Evolution',
#  'Black Mac',
#  "Speight's Old Dark",
#  'Sassy Red',
#  'Moa 5 Hop - Winter Ale',
#  "Monteith's Doppelbock Winter Ale",
#  'Taieri George',
#  "Porter's Rye Ale",
#  "Monteith's Barrel Aged Porter",
#  'Perfection',
#  'xeRRex',
#  'Tuatara Porter',
#  "Mac's Hop Rocker Pilsener",
#  'Digital IPA',
#  'Gunnamatta',
#  'Moa Imperial Stout (Aged In Pinot Noir Barrels)',
#  'Epic Lager',
#  'New Zealand Pilsner',
#  'Pot Kettle Black',
#  '1812',
#  'Rewired',
#  'Moa Pale Ale',
#  'Moa Methode',
#  'Harringtons Big John Special Reserve',
#  'M.P.A',
#  'Craftsman',
#  'Epic Larger',
#  'Epic Barrel Aged IPA',
#  'Epicurean Fig & Coffee',
#  'Patriot',
#  'Hippy Berliner',
#  'Tuatara APA',
#  'London Porter',
#  'Epic Mayhem',
#  'Moa St Josephs',
#  'Stonecutter',
#  'The Big Smoke',
#  'Pale Ale',
#  'Tuatara KAPAI',
#  'Tuatara Mot Eureka',
#  'APA',
#  'Flat White Coffee Milk Stout',
#  'Pernicious Weed',
#  'Elemental',
#  'Fresh Hopwired',
#  'Saison Sauvin',
#  'Death From Above',
#  'Epic Pale Ale',
#  'C!tra',
#  'Tuatara Double Trouble',
#  'Super Conductor',
#  'Epic Armageddon IPA',
#  'iStout',
#  'Hopwired',
#  'Epic Hop Zombie',
#  'Snow Weizen',
#  'Yebisu Black Beer',
#  'Coedo Kyara',
#  'Coedo Shiro',
#  'Coedo Shikkoku',
#  'Hitachino Nest Dai Dai Ale',
#  'Hitachino Nest Real Ginger Ale',
#  'Sapporo Premium Black Beer',
#  'Jubilation Ale',
#  "White Crane Ale (Rogue's Oregon Golden Ale)",
#  'Hitachino Nest Pale Ale',
#  'Buckwheat Ale',
#  'Shimaguni Stout',
#  'Ginga Kogen Weizen',
#  'Echigo Stout',
#  'Suiyoubi No Neko',
#  'Ise Kadoya IPA',
#  'Teikoku IPA',
#  'Hitachino Nest Red Rice Ale',
#  'Numazu Lager',
#  'Ise Kadoya Genmai Ale',
#  'Temple Garden Yuzu Ale',
#  'Hitachino Nest Weizen',
#  'Shiga Kogen IPA',
#  'Rising Sun Pale Ale',
#  'Tokyo Black',
#  'Yabai-Yabai Strong Scotch Ale',
#  'Hitachino Nest Commemorative Ale',
#  'Shizuoka Summer Mikan Ale',
#  'Single Take Session Ale',
#  'Dark Sky Imperial Stout',
#  'Yona Yona Ale',
#  'Baird Angry Boy Brown Ale',
#  'Hitachino Nest Japanese Classic Ale',
#  "Red Fox (Rogue's American Amber)",
#  'Samurai Barley Ale',
#  'Kurofune Porter',
#  'West Coast Wheat Wine',
#  'Hitachino Nest Extra High (XH)',
#  'Red Rose Amber Ale',
#  'Hitachino Nest Amber Ale',
#  'Minoh W-IPA',
#  'Hitachino Nest Yuzu Lager',
#  'Ozeno Yukidoke IPA',
#  'Hitachino Nest Saison Du Japon',
#  'Iwatekura Oyster Stout',
#  'The Carpenter\x92s Mikan Ale',
#  'Ginga Kogen Wheat Beer',
#  'Natsumikan Ale',
#  'Minoh Stout',
#  'Hitachino Nest Ancient Nipponia',
#  'Ise Kadoya Imperial Smoked Porter',
#  'Hitachino Nest Nipponia',
#  'Suruga Bay Imperial IPA',
#  'Hitachino Nest Anbai Ale',
#  'Kuri Kuro (Dark Chestnut Ale)',
#  'Hitachino Nest White Ale',
#  'Hitachino Nest Espresso Stout',
#  "Smithwick's Winter Spirit",
#  'Irish Wheat',
#  'Porterhouse Red',
#  'TSB',
#  'Guinness Original',
#  'Rebel Red',
#  'Howling Gale Ale',
#  'Oyster Stout',
#  "O'Shea's Traditional Irish Stout",
#  'Guinness Extra Stout (Original)',
#  'Chieftain IPA',
#  'Metalman Pale Ale',
#  'Copper Coast',
#  'Guinness Original (UK Version - 4.2%)',
#  'Guinness - Bulleit Bourbon-Aged',
#  "Murphy's Irish Stout",
#  'Galway Hooker Irish Pale Ale',
#  'Wrasslers XXXX Stout',
#  'Hop Head',
#  'Guinness Milk Stout: The Brewers Project',
#  'Plain Porter',
#  'Shandon Stout',
#  'West Indies Porter',
#  'Cael & Crede Ale',
#  'Beamish Irish Stout',
#  'Knockmealdown Porter',
#  "O'Hara's Barrel Aged Leann Folláin",
#  "Francis' Big Bangin IPA",
#  "O'Hara's Leann Folláin",
#  'Guinness Foreign Extra Stout',
#  'Guinness Special Export Stout / Antwerpen Stout',
#  'Celebration Stout',
#  'Guinness 200th Anniversary Export Stout',
#  'Baden Baden Golden',
#  'Colorado Appia',
#  'Eisenbahn Escura (Dunkel)',
#  'Eisenbahn Weizenbier',
#  'Colorado Berthô',
#  'Eisenbahn Strong Golden Ale',
#  'Baden Baden Dark Ale Stout',
#  'Eisenbahn Vigorosa (Weizenbock)',
#  'Baden Baden Red Ale Especial',
#  'Baden Baden 1999 Bitter Ale',
#  'Eisenbahn Pale Ale',
#  'Colorado Indica',
#  'Colorado Vixnu',
#  'Eisenbahn Lust',
#  'Eisenbahn Rauchbier',
#  'Belô Petroleum',
#  'Wals Petroleum',
#  'Colorado Ithaca / Guanabara',
#  'Wäls Quadruppel',
#  'Stiegl Radler Zitrone',
#  'Wieselburger Stammbräu',
#  'Zipfer Urtyp',
#  'Hopfenkönig',
#  'Hirter 1270',
#  'Stiegl Goldbräu',
#  'Villacher Märzen',
#  'Stiegl Pils',
#  'Rieder XXX Weisse',
#  'Stifter Bier (Red Ale)',
#  'Ottakringer Wiener Original',
#  'Schlägl Kristall',
#  'Grieskirchner Pils',
#  'Columbus Pils',
#  'Nivard',
#  'Grieskirchner Jörger Weisse',
#  'Schlägl Urquell',
#  'Edelweiss Hefetrub',
#  'Schlägl Bio-Roggen',
#  'Rieder India Pale Ale',
#  'Barleywine Ale',
#  'Stiegl Weisse Naturtrüb',
#  'Weisse (Whitebeer)',
#  'Stiegl Märzen',
#  'Schlägl Doppel Bock',
#  'Meinklang Ancient Grains Ale',
#  'Gösser Dark Beer',
#  'Naturtrüb',
#  'Stiegl Weizen Gold Hefefein',
#  'Schremser Roggen Bier',
#  'Doppelbock Dunkel',
#  'Granitbock',
#  'Benno',
#  'Kubelbier',
#  'Tak Pale Ale',
#  'Edelweiss Dunkel Weizenbier',
#  'Samichlaus Bier Helles',
#  'Original Munchner Hochzeitsbier Von 1810',
#  'Hirter Morchl',
#  'Stiegl Radler (Grapefruit)',
#  'Edelweiss Weissbier Snowfresh',
#  'Kramah India Pale Ale',
#  'Granitbock Ice',
#  'Gregorius',
#  'Heller Bock Saphir',
#  'NZ Victory Hop Devil IPA',
#  'Samichlaus Schwarzes',
#  'Paracelsus Zwickl',
#  'Edelweiss Weissbier Hefetrüb',
#  'Samichlaus Classic Bier',
#  'Lervig Lucky Jack',
#  'Augustiner Bräu Märzen Bier',
#  'Aass Bayer (Aass Dark)',
#  'Aass Juleøl',
#  'Krekling',
#  'India Pale Ale',
#  'Aass Genuine Pilsner',
#  'Wit',
#  'HaandBic',
#  'Fyr & Flamme',
#  'Dobbel Dose (Dobbel Dram)',
#  'Imperial DunkelWit',
#  'Havre Stout',
#  'Sweet & Sour',
#  'Ardenne Blond',
#  'Saison',
#  'Julebrygg (7%)',
#  'Tiger Tripel',
#  'Lervig Galaxy IPA',
#  'Hazy Days',
#  'Brown Ale',
#  'Sunturnbrew',
#  'Nissefar',
#  'Hesjeøl',
#  'Costa Rica (Coffee Porter)',
#  'Bestefar',
#  'Rye IPA',
#  'Underlig Jul',
#  'Ægir India Pale Ale',
#  'Perler For Svin',
#  'Aass Bock',
#  'Norwegian Wood',
#  'Special Holiday Ale - Nøgne Ø/Jolly Pumpkin Artisan Ales/Stone Brewing Co.',
#  'Imperial India Pale Ale #500',
#  'Konrads Stout',
#  'Dark Force',
#  'Tasty Juice',
#  'Imperial Brown Ale',
#  'Two Captains',
#  'Supersonic',
#  'Toasted Maple Stout',
#  '# 100',
#  'God Jul',
#  'Lervig / Hoppin’ Frog Sippin Into Darkness',
#  'Akevitt',
#  'Nøgne Ø / Terrapin Imperial Rye Porter',
#  'Haandbakk',
#  'Lervig / Way Beer - 3 Bean Stout',
#  'Horizon Tokyo Black',
#  "Odin's Tipple",
#  'Brewers Reserve Barley Wine (Aged In Bourbon Barrels)',
#  'Cuvée De Ranke',
#  'Oude Schaarbeekse Kriek',
#  'Moinette Blond',
#  'Trappistes Rochefort 6',
#  'Première (Red)',
#  'Avec Les Bons Voeux',
#  'Boon Oude Kriek Mariage Parfait',
#  'Brasserie Des Rocs Triple Impériale',
#  'Oud Beersel Oude Kriek Vieille',
#  'St. Amatus 12',
#  'Kriek De Ranke',
#  'Intense Red Oude Kriek',
#  'Oude Geuze Boon Black Label',
#  'Abbaye Des Rocs [Brasserie Des Rocs Brune]',
#  'Nath',
#  'Westmalle Trappist Dubbel',
#  'Oerbier',
#  'Goudenband',
#  'Oude Lambiek De Cam',
#  'Kasteel Barista Chocolate Quad Belgian Ale',
#  'Saison Dupont',
#  'Abbaye Des Rocs Grand Cru Belgian Special Brown',
#  'Stille Nacht',
#  'Duchesse De Bourgogne',
#  'Black Damnation II - Mocha Bomb',
#  "Oude Quetsche Tilquin à L'Ancienne Avec Prunes De Namur",
#  'Mamouche',
#  'La Chouffe',
#  'Christmas Ale',
#  'Houblon Chouffe Dobbelen IPA Tripel',
#  'Orval Trappist Ale',
#  'Cuvee Delphine',
#  "Oude Mûre Tilquin à L'ancienne",
#  'Oude Kriek De Cam',
#  'Tripel',
#  'Straffe Hendrik Heritage',
#  'Lambiek Special',
#  'Trappist Westvleteren Blond',
#  'Oude Geuze De Cam',
#  'Cuvee Moeder (Kriek)',
#  'Gulden Draak',
#  "Lambic D'Aunis",
#  'Black Albert',
#  'Gueuze Tilquin (Draught Version)',
#  'Achel Trappist Extra',
#  'Oude Gueuze',
#  'Duvel Belgian Golden Ale',
#  'Tripel Karmeliet',
#  'Abt 12 Oak Aged',
#  'Soleil De Minuit',
#  'Pannepot Grand Reserva',
#  'Pannepot Reserva',
#  'Girardin Gueuze 1882 (Black Label)',
#  'Oude Kriek',
#  'Lambic Rhubarbe',
#  'Fantôme Saison',
#  'Rodenbach Grand Cru',
#  'Westmalle Trappist Tripel',
#  'Grande Réserve (Blue)',
#  'Tripel Van De Garre',
#  'Cuvée Van De Keizer Blauw (Blue)',
#  'Rosé De Gambrinus',
#  "Oude Gueuze Tilquin à L'Ancienne",
#  'Pannepot',
#  'Cuvée Saint-Gilloise',
#  'Trappistes Rochefort 8',
#  'Cuvée Des Jacobins Rouge',
#  '50 Degrees North-4 Degrees East',
#  'Iris',
#  "Pinot D'Aunis",
#  'Kriek 100% Lambic',
#  "Oude Quetsche Tilquin à L'Ancienne",
#  'Oude (Gueuze Tilquin)²',
#  'Rodenbach Alexander',
#  'Oude Geuze',
#  'Black Damnation V - Double Black',
#  'Vigneronne',
#  'Rodenbach Caractère Rouge',
#  'Schaerbeekse Kriek',
#  'Gueuze 100% Lambic',
#  'Trappist Westvleteren 8 (VIII)',
#  'Oude Geuze Cuvée Armand & Gaston',
#  'Oude Geuze Golden Blend',
#  'Abt 12',
#  'Lou Pepe - Gueuze',
#  'Hommage',
#  'Framboos',
#  'Blåbær Lambik',
#  'Trappistes Rochefort 10',
#  'Saint Lamvinus',
#  'Oude Geuze Vintage',
#  'Lou Pepe - Framboise',
#  'Lou Pepe - Kriek',
#  'Trappist Westvleteren 12 (XII)',
#  'Zenne Y Frontera',
#  "Fou' Foune",
#  'Stranger Than Fiction',
#  'Four Winds IPA',
#  'Shipwreck IPA',
#  'Phaedra',
#  'Radio The Mothership',
#  'Full Moon Pale Ale',
#  'Collective Project: IPA No. 8',
#  'La Buteuse',
#  'Sovereign Super Saison',
#  'Dernière Volonté Réserve Spéciale En Fût De Pinot Noir',
#  'RPA (Rye Pale Ale)',
#  'Surround Sound (Simcoe, Galaxy & Citra)',
#  'Dernière Volonté',
#  'Blackstone Porter',
#  'Immodest',
#  'Collective Arts / Donut Monster - Origin of Darkness',
#  'Twenty Pounder',
#  'Eau Benite',
#  'Olde Deuteronomy',
#  'Back Hand Of God Stout',
#  'Pothole Filler Imperial Stout',
#  'Aromatherapy IPA',
#  'Play Dead IPA',
#  'Laser Show',
#  'Barrel Full Of Monkeys Imperial Stout',
#  'Flagship India Pale Ale',
#  'Série Signature IPA',
#  'Vexillum',
#  'Flying Monkeys Acadian Groove Canadian Maple Porter',
#  'Immoralité',
#  'Dominus Vobiscum Hibernus',
#  'Imperial IPA',
#  'Jam Up the Mash',
#  'Hopnotist',
#  'Roman Candle',
#  'Dominus Vobiscum Blanche',
#  'Amsterdam Barrel Aged Double Tempest',
#  'Lambda',
#  'Humulus Ludicrous',
#  'Burly Wine',
#  "Thor's Hammer Barley Wine",
#  'Dulcis Succubus',
#  'La Résolution',
#  'Grande Noirceur',
#  'Great Lakes Lake Effect',
#  'Farmageddon - Niagara Montmorency Cherry',
#  'Old Cellar Dweller',
#  'Dominus Vobiscum Triple',
#  'Old Kentucky Bastard',
#  'Great Lakes Octopus Wants To Fight IPA',
#  'Life in the Clouds',
#  'Witchshark',
#  'Black Oak Ten Bitter Years',
#  'Le Temps Noir',
#  'Jelly King',
#  'St-Ambroise Oatmeal Stout',
#  'Herbe à Détourne',
#  'Ransack the Universe',
#  'Ale Gâteau Forêt-Noire',
#  'Latus',
#  'IPA Du Nord-Est',
#  'Jutsu',
#  'Red Racer Imperial IPA',
#  'Juxtapose Wild IPA',
#  'Café Del Bastardo',
#  "Solstice D'hiver Réserve Spéciale En Fût De Bourbon",
#  'La Buteuse Brassin Spécial (Barrel Aged)',
#  'Great Lakes Karma Citra IPA',
#  'Hellwoods',
#  'La Vache Folle Imperial Milk Stout',
#  'Doppelbock Grande Cuvée Printemps',
#  'Yakima IPA',
#  'Raised By Wolves IPA',
#  'Great Lakes Thrust! An IPA',
#  'Naughty Hildegard ESB',
#  'Don De Dieu',
#  'Skeleton Key',
#  'Flying Monkeys The Chocolate Manifesto',
#  'Grande Cuvée Porter Baltique - Fûts De Bourbon Et Brandy',
#  'St-Ambroise Stout Impériale Russe',
#  'Dominus Vobiscum Lupulus',
#  'Terrible',
#  'Aphrodisiaque',
#  'Singularity',
#  "Solstice D'été Aux Framboises",
#  'Maudite',
#  'Bring Out Your Dead',
#  'Red Racer IPA (India Pale Ale)',
#  'Moralité',
#  'Fat Tug IPA',
#  'Unibroue 17 Grande Réserve',
#  'Trois Pistoles',
#  'Grande Cuvée Porter Baltique',
#  'Sartori Harvest IPA',
#  'Péché Mortel',
#  'Nectarous',
#  'La Fin Du Monde',
#  'Péché Mortel - Bourbon',
#  'Stout',
#  'Mornington Peninsula Brown Ale',
#  "Murray's Pilsner",
#  'Hargreaves Hill Pale',
#  "Murray's Big Wednesday Pale Ale",
#  'Mornington Peninsula IPA',
#  'Temptress Chocolate Porter',
#  "Murray's Spartacus",
#  'Mad Abbot Tripel',
#  'Nail Stout',
#  "Murray's Angry Man",
#  'Alpha Pale Ale',
#  'Mountain Goat Fancy Pants Amber Ale',
#  'Red Duck Golden Dragon',
#  'Chevalier Saison',
#  'Galaxy Single Hop IPA',
#  'Red Hill Weizenbock',
#  'Skunkworks Double IPA (Cognac Barrel Aged)',
#  'ESB',
#  'Grand Ridge Moonshine',
#  'Mornington Peninsula Pale',
#  'Harvest Pale Ale',
#  'Red Hill Bohemian Pilsner',
#  'Seventy Seven IPA',
#  'Red Hill Imperial Stout',
#  'Holgate Nut Brown Ale',
#  "Murray's Shawn's Fault",
#  'Growler American Brown Ale',
#  "Murray's Punk Monk",
#  "Murray's Icon 2IPA",
#  "Murray's Heart Of Darkness",
#  'Mountain Goat Rye IPA',
#  'Forty Four American Amber',
#  "Murray's Punch & Judy",
#  'Red Hill Hop Harvest Ale',
#  'Road Trip',
#  'Jamieson Beast IPA',
#  'Kooinda Black IPA - Full Nelson',
#  "Murray's Best Extra Porter",
#  'Black Giraffe',
#  'Seeing Double',
#  'Southwark Old Stout',
#  '4 Pines Dry Stout',
#  'Best Extra Stout',
#  'Raging Flem',
#  'Red Duck The Ox',
#  'Ace Of Spades',
#  'Spildt Mælk (Boys Don’t Cry Over Spilled Milk)',
#  'USAlive! (Alive)',
#  'Not Just Another Wit',
#  "Fuck Art - Let's Dance!",
#  'Reparationsbajer',
#  'Mosaic Black IPA',
#  'Snowball Saison Ale',
#  'Mine Is Bigger Than Yours',
#  "Santa's Little Helper 2012",
#  'Kremlin Crude',
#  'Mastodon Mother Puncher',
#  'By Udder Means',
#  'Amarillo Single Hop IPA',
#  'SpontanSeabuckthorn',
#  'The Fundamental Blackhorn',
#  'Liquid Confidential',
#  'Crooked Moon Tattoo Stockholm',
#  'Pacific Ale',
#  'Knappstein Reserve Lager',
#  'Karma Citra',
#  'Boris Imperial Stout',
#  'La Sirène Saison',
#  'Clout Stout',
#  'IIPA Imperial IPA',
#  'Little Creatures Pale Ale',
#  "Murray's Wild Thing Imperial Stout",
#  'Watermelon Warhead',
#  'Hop Hog',
#  'Black Maria',
#  'Amager / Grassroots - Shadow Pictures - Skyggebilleder',
#  'Gose To Hollywood',
#  'Black Magic Woman',
#  'Stateside IPA',
#  '19',
#  "It's Alive - White Wine Barrel Aged",
#  'Hallo Ich Bin Berliner Weisse - Passion Fruit',
#  "Monk's Brew",
#  'Limfjordsporter',
#  'Hallo Ich Bin Berliner Weisse - Raspberry',
#  'Spontanbeetroot',
#  'Spontandryhop Citra',
#  'Mikkeller / Grassroots Wheat Is The New Hops',
#  'Sur Amarillo',
#  'Sur Simcoe',
#  'Amager / Jester King - Danish Metal',
#  'Amager / Mikkeller - Hr. Frederiksens Væsel Brunch - Barrel-Aged',
#  'Santa Gose F%-It All',
#  'Beer Geek Brunch Weasel (Islay Edition)',
#  'Draft Bear',
#  'Forêt Du Centre (Light Toasted)',
#  'Dark Hops',
#  'Kaffestout',
#  'Rugporter',
#  'Nelson Sauvin Single Hop IPA',
#  'Spontancassis',
#  'Simcoe Single Hop IPA',
#  'Big Worster',
#  'Jule Mælk',
#  'Tomahawk Single Hop IPA',
#  'Amager / Mikkeller - Hr. Frederiksens Væsel Brunch',
#  'To Øl / Mikkeller Overall IIPA',
#  'Spontansauternes',
#  'Liquid Confidential (Cognac Barrel Aged)',
#  'Mosaic Imperial India Pale Ale',
#  'SpontanCherryFrederiksdal',
#  'Beer Geek Brunch Weasel (Bourbon Edition)',
#  'Double Black Mash',
#  'Liquid Confidential (Wine/Sherry Barrel Aged)',
#  'Crooked Moon Tattoo',
#  'Beer Hop Breakfast',
#  'Milk Stout',
#  'Black Ball Porter',
#  'Texas Ranger (Chipotle Porter)',
#  'Sur Citra',
#  'Hr. Frederiksen',
#  'Dangerously Close To Stupid',
#  'Spontanframboos',
#  'Mørke - Pumpernickel Porter',
#  'Gudeløs',
#  'Foggy Geezer',
#  'Beer Geek Dessert',
#  'Beer Geek Breakfast',
#  'Beer Geek Brunch Weasel - Cognac Edition',
#  'Black Malts And Body Salts',
#  'Lazurite',
#  'George',
#  'Citra Imperial India Pale Ale',
#  'Amager / Surly - Todd The Axe Man',
#  'Sort Mælk',
#  'Goliat',
#  'Beer Geek Vanilla Maple Shake',
#  ...]

# %%
a = 'Muscles'
b = 'Zywiec Bock'
c = 'Okocim Mocne'
test = recommand(b, c)
# Out:
# ('Zywiec Bock', 'Okocim Mocne')
# Zywiec Bock
# Okocim Mocne

# %%
test
# Out:
# [[3, 'Jenlain Ambrée'], [4, 'Hacker-Pschorr Oktoberfest Märzen'], [5, 'Zubr']]

# %%
set([1])
# Out:
# {1}
